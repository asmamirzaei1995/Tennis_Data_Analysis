# %%
import io
import zipfile
import os
import re

import pandas as pd
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ZIP_PATH = r'C:\Users\ASMA\Desktop\code\Tennis_project\data\raw data\tennis_data.zip'

print(os.path.exists(ZIP_PATH))
print(ZIP_PATH)
# Out:
# True
# C:\Users\ASMA\Desktop\code\Tennis_project\data\raw data\tennis_data.zip

# %%
outer_zip = zipfile.ZipFile(ZIP_PATH, 'r')

all_names = outer_zip.namelist()

day_zips = sorted(
    name for name in all_names
    if name.lower().endswith('.zip')
)

print("Number of daily ZIPs:", len(day_zips))
print(day_zips[:10])
# Out:
# Number of daily ZIPs: 60
# ['20240201.zip', '20240202.zip', '20240203.zip', '20240204.zip', '20240205.zip', '20240206.zip', '20240207.zip', '20240208.zip', '20240209.zip', '20240210.zip']

# %%
first_day_zip = day_zips[0]

print("First daily ZIP:")
print(first_day_zip)

daily_zip_bytes = outer_zip.read(first_day_zip)

with zipfile.ZipFile(io.BytesIO(daily_zip_bytes), 'r') as z:
    inner_names = z.namelist()

print("\nNumber of files inside:", len(inner_names))

for name in inner_names[:30]:
    print(name)
# Out:
# First daily ZIP:
# 20240201.zip
#
# Number of files inside: 4160
# ../../data/raw/raw_match_parquet/away_team_11998445.parquet
# ../../data/raw/raw_match_parquet/away_team_11998446.parquet
# ../../data/raw/raw_match_parquet/away_team_11998447.parquet
# ../../data/raw/raw_match_parquet/away_team_11998448.parquet
# ../../data/raw/raw_match_parquet/away_team_11998449.parquet
# ../../data/raw/raw_match_parquet/away_team_11998450.parquet
# ../../data/raw/raw_match_parquet/away_team_11998451.parquet
# ../../data/raw/raw_match_parquet/away_team_11998456.parquet
# ../../data/raw/raw_match_parquet/away_team_11998459.parquet
# ../../data/raw/raw_match_parquet/away_team_11998666.parquet
# ../../data/raw/raw_match_parquet/away_team_11998667.parquet
# ../../data/raw/raw_match_parquet/away_team_11998670.parquet
# ../../data/raw/raw_match_parquet/away_team_11998671.parquet
# ../../data/raw/raw_match_parquet/away_team_11998672.parquet
# ../../data/raw/raw_match_parquet/away_team_11998674.parquet
# ../../data/raw/raw_match_parquet/away_team_11998675.parquet
# ../../data/raw/raw_match_parquet/away_team_11998676.parquet
# ../../data/raw/raw_match_parquet/away_team_11998772.parquet
# ../../data/raw/raw_match_parquet/away_team_11998774.parquet
# ../../data/raw/raw_match_parquet/away_team_11998780.parquet
# ../../data/raw/raw_match_parquet/away_team_11998782.parquet
# ../../data/raw/raw_match_parquet/away_team_11998783.parquet
# ../../data/raw/raw_match_parquet/away_team_11998784.parquet
# ../../data/raw/raw_match_parquet/away_team_11998785.parquet
# ../../data/raw/raw_match_parquet/away_team_11998786.parquet
# ../../data/raw/raw_match_parquet/away_team_11999004.parquet
# ../../data/raw/raw_match_parquet/away_team_11999005.parquet
# ../../data/raw/raw_match_parquet/away_team_11999007.parquet
# ../../data/raw/raw_match_parquet/away_team_11999009.parquet
# ../../data/raw/raw_match_parquet/away_team_11999010.parquet

# %%
def find_parquet_files_in_zip(z, subfolder, prefix=None):
    """
    Find parquet files inside a daily ZIP without assuming
    the exact folder structure before data/raw/.
    """

    target_folder = f"/data/raw/{subfolder}/"

    matched = []

    for name in z.namelist():

        normalized = name.replace("\\", "/")

        # مسیر پوشه موردنظر باید داخل مسیر فایل وجود داشته باشد
        if target_folder not in "/" + normalized.lstrip("/"):
            continue

        # فقط parquet
        if not normalized.lower().endswith(".parquet"):
            continue

        # اگر prefix داده شده، نام فایل باید با آن شروع شود
        if prefix is not None:
            filename = os.path.basename(normalized)

            pattern = re.compile(
                rf'^{re.escape(prefix)}_\d+\.parquet$'
            )

            if not pattern.match(filename):
                continue

        matched.append(name)

    return matched

# %%
with zipfile.ZipFile(io.BytesIO(daily_zip_bytes), 'r') as z:

    event_files = find_parquet_files_in_zip(
        z,
        'raw_match_parquet',
        prefix='event'
    )

print("Event files found:", len(event_files))
print(event_files[:10])
# Out:
# Event files found: 285
# ['../../data/raw/raw_match_parquet/event_11974053.parquet', '../../data/raw/raw_match_parquet/event_11974066.parquet', '../../data/raw/raw_match_parquet/event_11998445.parquet', '../../data/raw/raw_match_parquet/event_11998446.parquet', '../../data/raw/raw_match_parquet/event_11998447.parquet', '../../data/raw/raw_match_parquet/event_11998448.parquet', '../../data/raw/raw_match_parquet/event_11998449.parquet', '../../data/raw/raw_match_parquet/event_11998450.parquet', '../../data/raw/raw_match_parquet/event_11998451.parquet', '../../data/raw/raw_match_parquet/event_11998456.parquet']

# %%
def read_prefix_day(day_zip, prefix, subfolder='raw_match_parquet'):

    # Read the daily ZIP from the outer ZIP
    daily_zip_bytes = outer_zip.read(day_zip)

    # Open daily ZIP in memory
    with zipfile.ZipFile(io.BytesIO(daily_zip_bytes), 'r') as z:

        # Find matching parquet files
        matched = find_parquet_files_in_zip(
            z,
            subfolder=subfolder,
            prefix=prefix
        )

        if not matched:
            return pd.DataFrame()

        tables = []

        for file_name in matched:

            with z.open(file_name) as f:
                table = pq.read_table(f)
                tables.append(table)

        if not tables:
            return pd.DataFrame()

        combined = pa.concat_tables(
            tables,
            promote_options='permissive'
        )

        return combined.to_pandas()

# %%
def read_prefix_all_days(day_zips, prefix, subfolder='raw_match_parquet'):

    parts = []

    for i, day_zip in enumerate(day_zips, start=1):

        df = read_prefix_day(
            day_zip,
            prefix,
            subfolder
        )

        if not df.empty:
            parts.append(df)

        print(
            f"{i:02d}/60  {os.path.basename(day_zip)}  ->  {df.shape}"
        )

    if not parts:
        return pd.DataFrame()

    return pd.concat(
        parts,
        ignore_index=True
    )

# %%
match_prefixes = [
    'event',
    'home_team',
    'away_team',
    'home_team_score',
    'away_team_score',
    'tournament',
    'season',
    'round',
    'venue',
    'time'
]

# %%
match_tables = {}

for p in match_prefixes:

    print("\n" + "=" * 60)
    print("Reading:", p)
    print("=" * 60)

    match_tables[p] = read_prefix_all_days(
        day_zips,
        p,
        subfolder='raw_match_parquet'
    )

    print(
        f"\nFINAL -> {p}: {match_tables[p].shape}"
    )
# Out:
# ============================================================
# Reading: event
# ============================================================
# 01/60  20240201.zip  ->  (285, 10)
# 02/60  20240202.zip  ->  (301, 10)
# 03/60  20240203.zip  ->  (612, 10)
# 04/60  20240204.zip  ->  (756, 10)
# 05/60  20240205.zip  ->  (599, 10)
# 06/60  20240206.zip  ->  (506, 10)
# 07/60  20240207.zip  ->  (445, 10)
# 08/60  20240208.zip  ->  (327, 10)
# 09/60  20240209.zip  ->  (228, 10)
# 10/60  20240210.zip  ->  (491, 10)
# 11/60  20240211.zip  ->  (714, 10)
# 12/60  20240212.zip  ->  (625, 10)
# 13/60  20240213.zip  ->  (579, 10)
# 14/60  20240214.zip  ->  (530, 10)
# 15/60  20240215.zip  ->  (443, 10)
# 16/60  20240216.zip  ->  (277, 10)
# 17/60  20240217.zip  ->  (511, 10)
# 18/60  20240218.zip  ->  (806, 10)
# 19/60  20240219.zip  ->  (767, 10)
# 20/60  20240220.zip  ->  (702, 10)
# 21/60  20240221.zip  ->  (541, 10)
# 22/60  20240222.zip  ->  (409, 10)
# 23/60  20240223.zip  ->  (244, 10)
# 24/60  20240224.zip  ->  (568, 10)
# 25/60  20240225.zip  ->  (895, 10)
# 26/60  20240226.zip  ->  (826, 10)
# 27/60  20240227.zip  ->  (853, 10)
# 28/60  20240228.zip  ->  (679, 10)
# 29/60  20240229.zip  ->  (450, 10)
# 30/60  20240301.zip  ->  (242, 10)
# 31/60  20240302.zip  ->  (530, 10)
# 32/60  20240303.zip  ->  (871, 10)
# 33/60  20240304.zip  ->  (837, 10)
# 34/60  20240305.zip  ->  (728, 10)
# 35/60  20240306.zip  ->  (627, 10)
# 36/60  20240307.zip  ->  (474, 10)
# 37/60  20240308.zip  ->  (304, 10)
# 38/60  20240309.zip  ->  (639, 10)
# 39/60  20240310.zip  ->  (1101, 10)
# 40/60  20240311.zip  ->  (1067, 10)
# 41/60  20240312.zip  ->  (888, 10)
# 42/60  20240313.zip  ->  (805, 10)
# 43/60  20240314.zip  ->  (609, 10)
# 44/60  20240315.zip  ->  (352, 10)
# 45/60  20240316.zip  ->  (673, 10)
# 46/60  20240317.zip  ->  (979, 10)
# 47/60  20240318.zip  ->  (897, 10)
# 48/60  20240319.zip  ->  (758, 10)
# 49/60  20240320.zip  ->  (664, 10)
# 50/60  20240321.zip  ->  (509, 10)
# 51/60  20240322.zip  ->  (303, 10)
# 52/60  20240323.zip  ->  (522, 10)
# 53/60  20240324.zip  ->  (749, 10)
# 54/60  20240325.zip  ->  (0, 0)
# 55/60  20240326.zip  ->  (612, 10)
# 56/60  20240327.zip  ->  (540, 10)
# 57/60  20240328.zip  ->  (351, 10)
# 58/60  20240329.zip  ->  (205, 10)
# 59/60  20240330.zip  ->  (497, 10)
# 60/60  20240331.zip  ->  (751, 10)
#
# FINAL -> event: (35053, 10)
#
# ============================================================
# Reading: home_team
# ============================================================
# 01/60  20240201.zip  ->  (273, 18)
# 02/60  20240202.zip  ->  (258, 18)
# 03/60  20240203.zip  ->  (425, 18)
# 04/60  20240204.zip  ->  (525, 18)
# 05/60  20240205.zip  ->  (481, 18)
# 06/60  20240206.zip  ->  (463, 18)
# 07/60  20240207.zip  ->  (424, 18)
# 08/60  20240208.zip  ->  (315, 18)
# 09/60  20240209.zip  ->  (223, 18)
# 10/60  20240210.zip  ->  (322, 18)
# 11/60  20240211.zip  ->  (451, 18)
# 12/60  20240212.zip  ->  (467, 18)
# 13/60  20240213.zip  ->  (503, 18)
# 14/60  20240214.zip  ->  (487, 18)
# 15/60  20240215.zip  ->  (412, 18)
# 16/60  20240216.zip  ->  (262, 18)
# 17/60  20240217.zip  ->  (299, 18)
# 18/60  20240218.zip  ->  (464, 18)
# 19/60  20240219.zip  ->  (555, 18)
# 20/60  20240220.zip  ->  (608, 18)
# 21/60  20240221.zip  ->  (498, 18)
# 22/60  20240222.zip  ->  (388, 18)
# 23/60  20240223.zip  ->  (238, 18)
# 24/60  20240224.zip  ->  (286, 18)
# 25/60  20240225.zip  ->  (457, 18)
# 26/60  20240226.zip  ->  (564, 18)
# 27/60  20240227.zip  ->  (694, 18)
# 28/60  20240228.zip  ->  (609, 18)
# 29/60  20240229.zip  ->  (418, 18)
# 30/60  20240301.zip  ->  (236, 18)
# 31/60  20240302.zip  ->  (249, 18)
# 32/60  20240303.zip  ->  (387, 18)
# 33/60  20240304.zip  ->  (510, 18)
# 34/60  20240305.zip  ->  (577, 18)
# 35/60  20240306.zip  ->  (547, 18)
# 36/60  20240307.zip  ->  (428, 18)
# 37/60  20240308.zip  ->  (292, 18)
# 38/60  20240309.zip  ->  (325, 18)
# 39/60  20240310.zip  ->  (526, 18)
# 40/60  20240311.zip  ->  (635, 18)
# 41/60  20240312.zip  ->  (670, 18)
# 42/60  20240313.zip  ->  (698, 18)
# 43/60  20240314.zip  ->  (553, 18)
# 44/60  20240315.zip  ->  (335, 18)
# 45/60  20240316.zip  ->  (315, 18)
# 46/60  20240317.zip  ->  (435, 18)
# 47/60  20240318.zip  ->  (558, 18)
# 48/60  20240319.zip  ->  (603, 18)
# 49/60  20240320.zip  ->  (573, 18)
# 50/60  20240321.zip  ->  (469, 18)
# 51/60  20240322.zip  ->  (289, 18)
# 52/60  20240323.zip  ->  (324, 18)
# 53/60  20240324.zip  ->  (453, 18)
# 54/60  20240325.zip  ->  (0, 0)
# 55/60  20240326.zip  ->  (528, 18)
# 56/60  20240327.zip  ->  (490, 18)
# 57/60  20240328.zip  ->  (321, 18)
# 58/60  20240329.zip  ->  (198, 18)
# 59/60  20240330.zip  ->  (284, 18)
# 60/60  20240331.zip  ->  (433, 18)
#
# FINAL -> home_team: (25610, 18)
#
# ============================================================
# Reading: away_team
# ============================================================
# 01/60  20240201.zip  ->  (269, 18)
# 02/60  20240202.zip  ->  (258, 18)
# 03/60  20240203.zip  ->  (419, 18)
# 04/60  20240204.zip  ->  (511, 18)
# 05/60  20240205.zip  ->  (470, 18)
# 06/60  20240206.zip  ->  (458, 18)
# 07/60  20240207.zip  ->  (415, 18)
# 08/60  20240208.zip  ->  (310, 18)
# 09/60  20240209.zip  ->  (225, 18)
# 10/60  20240210.zip  ->  (322, 18)
# 11/60  20240211.zip  ->  (446, 18)
# 12/60  20240212.zip  ->  (444, 18)
# 13/60  20240213.zip  ->  (486, 18)
# 14/60  20240214.zip  ->  (478, 18)
# 15/60  20240215.zip  ->  (413, 18)
# 16/60  20240216.zip  ->  (266, 18)
# 17/60  20240217.zip  ->  (289, 18)
# 18/60  20240218.zip  ->  (433, 18)
# 19/60  20240219.zip  ->  (507, 18)
# 20/60  20240220.zip  ->  (590, 18)
# 21/60  20240221.zip  ->  (511, 18)
# 22/60  20240222.zip  ->  (388, 18)
# 23/60  20240223.zip  ->  (239, 18)
# 24/60  20240224.zip  ->  (295, 18)
# 25/60  20240225.zip  ->  (408, 18)
# 26/60  20240226.zip  ->  (476, 18)
# 27/60  20240227.zip  ->  (642, 18)
# 28/60  20240228.zip  ->  (596, 18)
# 29/60  20240229.zip  ->  (416, 18)
# 30/60  20240301.zip  ->  (233, 18)
# 31/60  20240302.zip  ->  (222, 18)
# 32/60  20240303.zip  ->  (317, 18)
# 33/60  20240304.zip  ->  (401, 18)
# 34/60  20240305.zip  ->  (501, 18)
# 35/60  20240306.zip  ->  (527, 18)
# 36/60  20240307.zip  ->  (428, 18)
# 37/60  20240308.zip  ->  (296, 18)
# 38/60  20240309.zip  ->  (308, 18)
# 39/60  20240310.zip  ->  (434, 18)
# 40/60  20240311.zip  ->  (504, 18)
# 41/60  20240312.zip  ->  (574, 18)
# 42/60  20240313.zip  ->  (659, 18)
# 43/60  20240314.zip  ->  (540, 18)
# 44/60  20240315.zip  ->  (330, 18)
# 45/60  20240316.zip  ->  (322, 18)
# 46/60  20240317.zip  ->  (383, 18)
# 47/60  20240318.zip  ->  (455, 18)
# 48/60  20240319.zip  ->  (553, 18)
# 49/60  20240320.zip  ->  (575, 18)
# 50/60  20240321.zip  ->  (466, 18)
# 51/60  20240322.zip  ->  (293, 18)
# 52/60  20240323.zip  ->  (321, 18)
# 53/60  20240324.zip  ->  (410, 18)
# 54/60  20240325.zip  ->  (0, 0)
# 55/60  20240326.zip  ->  (488, 18)
# 56/60  20240327.zip  ->  (483, 18)
# 57/60  20240328.zip  ->  (326, 18)
# 58/60  20240329.zip  ->  (198, 18)
# 59/60  20240330.zip  ->  (277, 18)
# 60/60  20240331.zip  ->  (399, 18)
#
# FINAL -> away_team: (24203, 18)
#
# ============================================================
# Reading: home_team_score
# ============================================================
# 01/60  20240201.zip  ->  (285, 14)
# 02/60  20240202.zip  ->  (301, 14)
# 03/60  20240203.zip  ->  (612, 14)
# 04/60  20240204.zip  ->  (756, 14)
# 05/60  20240205.zip  ->  (599, 14)
# 06/60  20240206.zip  ->  (506, 14)
# 07/60  20240207.zip  ->  (445, 14)
# 08/60  20240208.zip  ->  (327, 14)
# 09/60  20240209.zip  ->  (228, 14)
# 10/60  20240210.zip  ->  (491, 14)
# 11/60  20240211.zip  ->  (714, 14)
# 12/60  20240212.zip  ->  (625, 14)
# 13/60  20240213.zip  ->  (579, 14)
# 14/60  20240214.zip  ->  (530, 14)
# 15/60  20240215.zip  ->  (443, 14)
# 16/60  20240216.zip  ->  (277, 14)
# 17/60  20240217.zip  ->  (511, 14)
# 18/60  20240218.zip  ->  (806, 14)
# 19/60  20240219.zip  ->  (767, 14)
# 20/60  20240220.zip  ->  (702, 14)
# 21/60  20240221.zip  ->  (541, 14)
# 22/60  20240222.zip  ->  (409, 14)
# 23/60  20240223.zip  ->  (244, 14)
# 24/60  20240224.zip  ->  (568, 14)
# 25/60  20240225.zip  ->  (895, 14)
# 26/60  20240226.zip  ->  (826, 14)
# 27/60  20240227.zip  ->  (853, 14)
# 28/60  20240228.zip  ->  (679, 14)
# 29/60  20240229.zip  ->  (450, 14)
# 30/60  20240301.zip  ->  (242, 14)
# 31/60  20240302.zip  ->  (530, 14)
# 32/60  20240303.zip  ->  (871, 14)
# 33/60  20240304.zip  ->  (837, 14)
# 34/60  20240305.zip  ->  (728, 14)
# 35/60  20240306.zip  ->  (627, 14)
# 36/60  20240307.zip  ->  (474, 14)
# 37/60  20240308.zip  ->  (304, 14)
# 38/60  20240309.zip  ->  (639, 14)
# 39/60  20240310.zip  ->  (1101, 14)
# 40/60  20240311.zip  ->  (1067, 14)
# 41/60  20240312.zip  ->  (888, 14)
# 42/60  20240313.zip  ->  (805, 14)
# 43/60  20240314.zip  ->  (609, 14)
# 44/60  20240315.zip  ->  (352, 14)
# 45/60  20240316.zip  ->  (673, 14)
# 46/60  20240317.zip  ->  (979, 14)
# 47/60  20240318.zip  ->  (897, 14)
# 48/60  20240319.zip  ->  (758, 14)
# 49/60  20240320.zip  ->  (664, 14)
# 50/60  20240321.zip  ->  (509, 14)
# 51/60  20240322.zip  ->  (303, 14)
# 52/60  20240323.zip  ->  (522, 14)
# 53/60  20240324.zip  ->  (749, 14)
# 54/60  20240325.zip  ->  (111, 14)
# 55/60  20240326.zip  ->  (612, 14)
# 56/60  20240327.zip  ->  (540, 14)
# 57/60  20240328.zip  ->  (351, 14)
# 58/60  20240329.zip  ->  (205, 14)
# 59/60  20240330.zip  ->  (497, 14)
# 60/60  20240331.zip  ->  (751, 14)
#
# FINAL -> home_team_score: (35164, 14)
#
# ============================================================
# Reading: away_team_score
# ============================================================
# 01/60  20240201.zip  ->  (285, 14)
# 02/60  20240202.zip  ->  (301, 14)
# 03/60  20240203.zip  ->  (612, 14)
# 04/60  20240204.zip  ->  (756, 14)
# 05/60  20240205.zip  ->  (599, 14)
# 06/60  20240206.zip  ->  (506, 14)
# 07/60  20240207.zip  ->  (445, 14)
# 08/60  20240208.zip  ->  (327, 14)
# 09/60  20240209.zip  ->  (228, 14)
# 10/60  20240210.zip  ->  (491, 14)
# 11/60  20240211.zip  ->  (714, 14)
# 12/60  20240212.zip  ->  (625, 14)
# 13/60  20240213.zip  ->  (579, 14)
# 14/60  20240214.zip  ->  (530, 14)
# 15/60  20240215.zip  ->  (443, 14)
# 16/60  20240216.zip  ->  (277, 14)
# 17/60  20240217.zip  ->  (511, 14)
# 18/60  20240218.zip  ->  (806, 14)
# 19/60  20240219.zip  ->  (767, 14)
# 20/60  20240220.zip  ->  (702, 14)
# 21/60  20240221.zip  ->  (541, 14)
# 22/60  20240222.zip  ->  (409, 14)
# 23/60  20240223.zip  ->  (244, 14)
# 24/60  20240224.zip  ->  (568, 14)
# 25/60  20240225.zip  ->  (895, 14)
# 26/60  20240226.zip  ->  (826, 14)
# 27/60  20240227.zip  ->  (853, 14)
# 28/60  20240228.zip  ->  (679, 14)
# 29/60  20240229.zip  ->  (450, 14)
# 30/60  20240301.zip  ->  (242, 14)
# 31/60  20240302.zip  ->  (530, 14)
# 32/60  20240303.zip  ->  (871, 14)
# 33/60  20240304.zip  ->  (837, 14)
# 34/60  20240305.zip  ->  (728, 14)
# 35/60  20240306.zip  ->  (627, 14)
# 36/60  20240307.zip  ->  (474, 14)
# 37/60  20240308.zip  ->  (304, 14)
# 38/60  20240309.zip  ->  (639, 14)
# 39/60  20240310.zip  ->  (1101, 14)
# 40/60  20240311.zip  ->  (1067, 14)
# 41/60  20240312.zip  ->  (888, 14)
# 42/60  20240313.zip  ->  (805, 14)
# 43/60  20240314.zip  ->  (609, 14)
# 44/60  20240315.zip  ->  (352, 14)
# 45/60  20240316.zip  ->  (673, 14)
# 46/60  20240317.zip  ->  (979, 14)
# 47/60  20240318.zip  ->  (897, 14)
# 48/60  20240319.zip  ->  (758, 14)
# 49/60  20240320.zip  ->  (664, 14)
# 50/60  20240321.zip  ->  (509, 14)
# 51/60  20240322.zip  ->  (303, 14)
# 52/60  20240323.zip  ->  (522, 14)
# 53/60  20240324.zip  ->  (749, 14)
# 54/60  20240325.zip  ->  (0, 0)
# 55/60  20240326.zip  ->  (612, 14)
# 56/60  20240327.zip  ->  (540, 14)
# 57/60  20240328.zip  ->  (351, 14)
# 58/60  20240329.zip  ->  (205, 14)
# 59/60  20240330.zip  ->  (497, 14)
# 60/60  20240331.zip  ->  (751, 14)
#
# FINAL -> away_team_score: (35053, 14)
#
# ============================================================
# Reading: tournament
# ============================================================
# 01/60  20240201.zip  ->  (285, 16)
# 02/60  20240202.zip  ->  (301, 16)
# 03/60  20240203.zip  ->  (612, 16)
# 04/60  20240204.zip  ->  (756, 16)
# 05/60  20240205.zip  ->  (599, 16)
# 06/60  20240206.zip  ->  (506, 16)
# 07/60  20240207.zip  ->  (445, 16)
# 08/60  20240208.zip  ->  (327, 16)
# 09/60  20240209.zip  ->  (228, 16)
# 10/60  20240210.zip  ->  (491, 16)
# 11/60  20240211.zip  ->  (714, 16)
# 12/60  20240212.zip  ->  (625, 16)
# 13/60  20240213.zip  ->  (579, 16)
# 14/60  20240214.zip  ->  (530, 16)
# 15/60  20240215.zip  ->  (443, 16)
# 16/60  20240216.zip  ->  (277, 16)
# 17/60  20240217.zip  ->  (511, 16)
# 18/60  20240218.zip  ->  (806, 16)
# 19/60  20240219.zip  ->  (767, 16)
# 20/60  20240220.zip  ->  (702, 16)
# 21/60  20240221.zip  ->  (541, 16)
# 22/60  20240222.zip  ->  (409, 16)
# 23/60  20240223.zip  ->  (244, 16)
# 24/60  20240224.zip  ->  (568, 16)
# 25/60  20240225.zip  ->  (895, 16)
# 26/60  20240226.zip  ->  (826, 16)
# 27/60  20240227.zip  ->  (853, 16)
# 28/60  20240228.zip  ->  (679, 16)
# 29/60  20240229.zip  ->  (450, 16)
# 30/60  20240301.zip  ->  (242, 16)
# 31/60  20240302.zip  ->  (530, 16)
# 32/60  20240303.zip  ->  (871, 16)
# 33/60  20240304.zip  ->  (837, 16)
# 34/60  20240305.zip  ->  (728, 16)
# 35/60  20240306.zip  ->  (627, 16)
# 36/60  20240307.zip  ->  (474, 16)
# 37/60  20240308.zip  ->  (304, 16)
# 38/60  20240309.zip  ->  (639, 16)
# 39/60  20240310.zip  ->  (1101, 16)
# 40/60  20240311.zip  ->  (1067, 16)
# 41/60  20240312.zip  ->  (888, 16)
# 42/60  20240313.zip  ->  (805, 16)
# 43/60  20240314.zip  ->  (609, 16)
# 44/60  20240315.zip  ->  (352, 16)
# 45/60  20240316.zip  ->  (673, 16)
# 46/60  20240317.zip  ->  (979, 16)
# 47/60  20240318.zip  ->  (897, 16)
# 48/60  20240319.zip  ->  (758, 16)
# 49/60  20240320.zip  ->  (664, 16)
# 50/60  20240321.zip  ->  (509, 16)
# 51/60  20240322.zip  ->  (303, 16)
# 52/60  20240323.zip  ->  (522, 16)
# 53/60  20240324.zip  ->  (749, 16)
# 54/60  20240325.zip  ->  (618, 16)
# 55/60  20240326.zip  ->  (612, 16)
# 56/60  20240327.zip  ->  (540, 16)
# 57/60  20240328.zip  ->  (351, 16)
# 58/60  20240329.zip  ->  (205, 16)
# 59/60  20240330.zip  ->  (497, 16)
# 60/60  20240331.zip  ->  (751, 16)
#
# FINAL -> tournament: (35671, 16)
#
# ============================================================
# Reading: season
# ============================================================
# 01/60  20240201.zip  ->  (285, 4)
# 02/60  20240202.zip  ->  (301, 4)
# 03/60  20240203.zip  ->  (612, 4)
# 04/60  20240204.zip  ->  (756, 4)
# 05/60  20240205.zip  ->  (599, 4)
# 06/60  20240206.zip  ->  (506, 4)
# 07/60  20240207.zip  ->  (445, 4)
# 08/60  20240208.zip  ->  (327, 4)
# 09/60  20240209.zip  ->  (228, 4)
# 10/60  20240210.zip  ->  (491, 4)
# 11/60  20240211.zip  ->  (714, 4)
# 12/60  20240212.zip  ->  (625, 4)
# 13/60  20240213.zip  ->  (579, 4)
# 14/60  20240214.zip  ->  (530, 4)
# 15/60  20240215.zip  ->  (443, 4)
# 16/60  20240216.zip  ->  (277, 4)
# 17/60  20240217.zip  ->  (511, 4)
# 18/60  20240218.zip  ->  (806, 4)
# 19/60  20240219.zip  ->  (767, 4)
# 20/60  20240220.zip  ->  (702, 4)
# 21/60  20240221.zip  ->  (541, 4)
# 22/60  20240222.zip  ->  (409, 4)
# 23/60  20240223.zip  ->  (244, 4)
# 24/60  20240224.zip  ->  (568, 4)
# 25/60  20240225.zip  ->  (895, 4)
# 26/60  20240226.zip  ->  (826, 4)
# 27/60  20240227.zip  ->  (853, 4)
# 28/60  20240228.zip  ->  (679, 4)
# 29/60  20240229.zip  ->  (450, 4)
# 30/60  20240301.zip  ->  (242, 4)
# 31/60  20240302.zip  ->  (530, 4)
# 32/60  20240303.zip  ->  (871, 4)
# 33/60  20240304.zip  ->  (837, 4)
# 34/60  20240305.zip  ->  (728, 4)
# 35/60  20240306.zip  ->  (627, 4)
# 36/60  20240307.zip  ->  (474, 4)
# 37/60  20240308.zip  ->  (304, 4)
# 38/60  20240309.zip  ->  (639, 4)
# 39/60  20240310.zip  ->  (1101, 4)
# 40/60  20240311.zip  ->  (1067, 4)
# 41/60  20240312.zip  ->  (888, 4)
# 42/60  20240313.zip  ->  (805, 4)
# 43/60  20240314.zip  ->  (609, 4)
# 44/60  20240315.zip  ->  (352, 4)
# 45/60  20240316.zip  ->  (673, 4)
# 46/60  20240317.zip  ->  (979, 4)
# 47/60  20240318.zip  ->  (897, 4)
# 48/60  20240319.zip  ->  (758, 4)
# 49/60  20240320.zip  ->  (664, 4)
# 50/60  20240321.zip  ->  (509, 4)
# 51/60  20240322.zip  ->  (303, 4)
# 52/60  20240323.zip  ->  (522, 4)
# 53/60  20240324.zip  ->  (749, 4)
# 54/60  20240325.zip  ->  (618, 4)
# 55/60  20240326.zip  ->  (612, 4)
# 56/60  20240327.zip  ->  (540, 4)
# 57/60  20240328.zip  ->  (351, 4)
# 58/60  20240329.zip  ->  (205, 4)
# 59/60  20240330.zip  ->  (497, 4)
# 60/60  20240331.zip  ->  (751, 4)
#
# FINAL -> season: (35671, 4)
#
# ============================================================
# Reading: round
# ============================================================
# 01/60  20240201.zip  ->  (262, 5)
# 02/60  20240202.zip  ->  (187, 5)
# 03/60  20240203.zip  ->  (169, 5)
# 04/60  20240204.zip  ->  (128, 5)
# 05/60  20240205.zip  ->  (170, 5)
# 06/60  20240206.zip  ->  (329, 5)
# 07/60  20240207.zip  ->  (413, 5)
# 08/60  20240208.zip  ->  (327, 5)
# 09/60  20240209.zip  ->  (220, 5)
# 10/60  20240210.zip  ->  (196, 5)
# 11/60  20240211.zip  ->  (194, 5)
# 12/60  20240212.zip  ->  (182, 5)
# 13/60  20240213.zip  ->  (374, 5)
# 14/60  20240214.zip  ->  (476, 5)
# 15/60  20240215.zip  ->  (426, 5)
# 16/60  20240216.zip  ->  (269, 5)
# 17/60  20240217.zip  ->  (181, 5)
# 18/60  20240218.zip  ->  (174, 5)
# 19/60  20240219.zip  ->  (205, 5)
# 20/60  20240220.zip  ->  (469, 5)
# 21/60  20240221.zip  ->  (521, 5)
# 22/60  20240222.zip  ->  (409, 5)
# 23/60  20240223.zip  ->  (244, 5)
# 24/60  20240224.zip  ->  (208, 5)
# 25/60  20240225.zip  ->  (173, 5)
# 26/60  20240226.zip  ->  (216, 5)
# 27/60  20240227.zip  ->  (558, 5)
# 28/60  20240228.zip  ->  (637, 5)
# 29/60  20240229.zip  ->  (450, 5)
# 30/60  20240301.zip  ->  (242, 5)
# 31/60  20240302.zip  ->  (157, 5)
# 32/60  20240303.zip  ->  (116, 5)
# 33/60  20240304.zip  ->  (178, 5)
# 34/60  20240305.zip  ->  (456, 5)
# 35/60  20240306.zip  ->  (593, 5)
# 36/60  20240307.zip  ->  (474, 5)
# 37/60  20240308.zip  ->  (304, 5)
# 38/60  20240309.zip  ->  (228, 5)
# 39/60  20240310.zip  ->  (170, 5)
# 40/60  20240311.zip  ->  (230, 5)
# 41/60  20240312.zip  ->  (543, 5)
# 42/60  20240313.zip  ->  (762, 5)
# 43/60  20240314.zip  ->  (602, 5)
# 44/60  20240315.zip  ->  (345, 5)
# 45/60  20240316.zip  ->  (356, 5)
# 46/60  20240317.zip  ->  (152, 5)
# 47/60  20240318.zip  ->  (228, 5)
# 48/60  20240319.zip  ->  (493, 5)
# 49/60  20240320.zip  ->  (635, 5)
# 50/60  20240321.zip  ->  (509, 5)
# 51/60  20240322.zip  ->  (303, 5)
# 52/60  20240323.zip  ->  (209, 5)
# 53/60  20240324.zip  ->  (184, 5)
# 54/60  20240325.zip  ->  (201, 5)
# 55/60  20240326.zip  ->  (411, 5)
# 56/60  20240327.zip  ->  (513, 5)
# 57/60  20240328.zip  ->  (351, 5)
# 58/60  20240329.zip  ->  (205, 5)
# 59/60  20240330.zip  ->  (196, 5)
# 60/60  20240331.zip  ->  (170, 5)
#
# FINAL -> round: (19283, 5)
#
# ============================================================
# Reading: venue
# ============================================================
# 01/60  20240201.zip  ->  (285, 5)
# 02/60  20240202.zip  ->  (301, 5)
# 03/60  20240203.zip  ->  (612, 5)
# 04/60  20240204.zip  ->  (753, 5)
# 05/60  20240205.zip  ->  (592, 5)
# 06/60  20240206.zip  ->  (500, 5)
# 07/60  20240207.zip  ->  (441, 5)
# 08/60  20240208.zip  ->  (324, 5)
# 09/60  20240209.zip  ->  (227, 5)
# 10/60  20240210.zip  ->  (488, 5)
# 11/60  20240211.zip  ->  (708, 5)
# 12/60  20240212.zip  ->  (619, 5)
# 13/60  20240213.zip  ->  (576, 5)
# 14/60  20240214.zip  ->  (528, 5)
# 15/60  20240215.zip  ->  (443, 5)
# 16/60  20240216.zip  ->  (277, 5)
# 17/60  20240217.zip  ->  (511, 5)
# 18/60  20240218.zip  ->  (804, 5)
# 19/60  20240219.zip  ->  (767, 5)
# 20/60  20240220.zip  ->  (700, 5)
# 21/60  20240221.zip  ->  (539, 5)
# 22/60  20240222.zip  ->  (409, 5)
# 23/60  20240223.zip  ->  (239, 5)
# 24/60  20240224.zip  ->  (568, 5)
# 25/60  20240225.zip  ->  (894, 5)
# 26/60  20240226.zip  ->  (822, 5)
# 27/60  20240227.zip  ->  (842, 5)
# 28/60  20240228.zip  ->  (675, 5)
# 29/60  20240229.zip  ->  (449, 5)
# 30/60  20240301.zip  ->  (242, 5)
# 31/60  20240302.zip  ->  (527, 5)
# 32/60  20240303.zip  ->  (868, 5)
# 33/60  20240304.zip  ->  (833, 5)
# 34/60  20240305.zip  ->  (727, 5)
# 35/60  20240306.zip  ->  (627, 5)
# 36/60  20240307.zip  ->  (473, 5)
# 37/60  20240308.zip  ->  (290, 5)
# 38/60  20240309.zip  ->  (620, 5)
# 39/60  20240310.zip  ->  (1094, 5)
# 40/60  20240311.zip  ->  (1064, 5)
# 41/60  20240312.zip  ->  (884, 5)
# 42/60  20240313.zip  ->  (803, 5)
# 43/60  20240314.zip  ->  (607, 5)
# 44/60  20240315.zip  ->  (326, 5)
# 45/60  20240316.zip  ->  (644, 5)
# 46/60  20240317.zip  ->  (972, 5)
# 47/60  20240318.zip  ->  (896, 5)
# 48/60  20240319.zip  ->  (753, 5)
# 49/60  20240320.zip  ->  (656, 5)
# 50/60  20240321.zip  ->  (504, 5)
# 51/60  20240322.zip  ->  (290, 5)
# 52/60  20240323.zip  ->  (522, 5)
# 53/60  20240324.zip  ->  (747, 5)
# 54/60  20240325.zip  ->  (613, 5)
# 55/60  20240326.zip  ->  (607, 5)
# 56/60  20240327.zip  ->  (539, 5)
# 57/60  20240328.zip  ->  (351, 5)
# 58/60  20240329.zip  ->  (204, 5)
# 59/60  20240330.zip  ->  (496, 5)
# 60/60  20240331.zip  ->  (751, 5)
#
# FINAL -> venue: (35423, 5)
#
# ============================================================
# Reading: time
# ============================================================
# 01/60  20240201.zip  ->  (285, 7)
# 02/60  20240202.zip  ->  (301, 7)
# 03/60  20240203.zip  ->  (612, 7)
# 04/60  20240204.zip  ->  (756, 7)
# 05/60  20240205.zip  ->  (599, 7)
# 06/60  20240206.zip  ->  (506, 7)
# 07/60  20240207.zip  ->  (445, 7)
# 08/60  20240208.zip  ->  (327, 7)
# 09/60  20240209.zip  ->  (228, 7)
# 10/60  20240210.zip  ->  (491, 7)
# 11/60  20240211.zip  ->  (714, 7)
# 12/60  20240212.zip  ->  (625, 7)
# 13/60  20240213.zip  ->  (579, 7)
# 14/60  20240214.zip  ->  (530, 7)
# 15/60  20240215.zip  ->  (443, 7)
# 16/60  20240216.zip  ->  (277, 7)
# 17/60  20240217.zip  ->  (511, 7)
# 18/60  20240218.zip  ->  (806, 7)
# 19/60  20240219.zip  ->  (767, 7)
# 20/60  20240220.zip  ->  (702, 7)
# 21/60  20240221.zip  ->  (541, 7)
# 22/60  20240222.zip  ->  (409, 7)
# 23/60  20240223.zip  ->  (244, 7)
# 24/60  20240224.zip  ->  (568, 7)
# 25/60  20240225.zip  ->  (895, 7)
# 26/60  20240226.zip  ->  (826, 7)
# 27/60  20240227.zip  ->  (853, 7)
# 28/60  20240228.zip  ->  (679, 7)
# 29/60  20240229.zip  ->  (450, 7)
# 30/60  20240301.zip  ->  (242, 7)
# 31/60  20240302.zip  ->  (530, 7)
# 32/60  20240303.zip  ->  (871, 7)
# 33/60  20240304.zip  ->  (837, 7)
# 34/60  20240305.zip  ->  (728, 7)
# 35/60  20240306.zip  ->  (627, 7)
# 36/60  20240307.zip  ->  (474, 7)
# 37/60  20240308.zip  ->  (304, 7)
# 38/60  20240309.zip  ->  (639, 7)
# 39/60  20240310.zip  ->  (1101, 7)
# 40/60  20240311.zip  ->  (1067, 7)
# 41/60  20240312.zip  ->  (888, 7)
# 42/60  20240313.zip  ->  (805, 7)
# 43/60  20240314.zip  ->  (609, 7)
# 44/60  20240315.zip  ->  (352, 7)
# 45/60  20240316.zip  ->  (673, 7)
# 46/60  20240317.zip  ->  (979, 7)
# 47/60  20240318.zip  ->  (897, 7)
# 48/60  20240319.zip  ->  (758, 7)
# 49/60  20240320.zip  ->  (664, 7)
# 50/60  20240321.zip  ->  (509, 7)
# 51/60  20240322.zip  ->  (303, 7)
# 52/60  20240323.zip  ->  (522, 7)
# 53/60  20240324.zip  ->  (749, 7)
# 54/60  20240325.zip  ->  (618, 7)
# 55/60  20240326.zip  ->  (612, 7)
# 56/60  20240327.zip  ->  (540, 7)
# 57/60  20240328.zip  ->  (351, 7)
# 58/60  20240329.zip  ->  (205, 7)
# 59/60  20240330.zip  ->  (497, 7)
# 60/60  20240331.zip  ->  (751, 7)
#
# FINAL -> time: (35671, 7)

# %%
flat_folders = {
    'votes': 'raw_votes_parquet',
    'power': 'raw_tennis_power_parquet',
    'statistics': 'raw_statistics_parquet',
    'point_by_point': 'raw_point_by_point_parquet',
    'odds': 'raw_odds_parquet'
}

# %%
def read_flat_folder_all_days(day_zips, subfolder):

    day_parts = []

    for i, day_zip in enumerate(day_zips, start=1):

        daily_zip_bytes = outer_zip.read(day_zip)

        with zipfile.ZipFile(
            io.BytesIO(daily_zip_bytes),
            'r'
        ) as z:

            files = find_parquet_files_in_zip(
                z,
                subfolder=subfolder,
                prefix=None
            )

            if not files:
                print(
                    f"{i:02d}/60  "
                    f"{os.path.basename(day_zip)}  ->  no files"
                )
                continue

            tables = []

            for file_name in files:

                with z.open(file_name) as f:

                    table = pq.read_table(f)

                    tables.append(table)

            if not tables:
                continue

            day_table = pa.concat_tables(
                tables,
                promote_options='permissive'
            )

            day_df = day_table.to_pandas()

            # Add source day
            day_df['source_day'] = os.path.splitext(
                os.path.basename(day_zip)
            )[0]

            day_parts.append(day_df)

            print(
                f"{i:02d}/60  "
                f"{os.path.basename(day_zip)}  ->  "
                f"{day_df.shape}"
            )

    if not day_parts:
        return pd.DataFrame()

    return pd.concat(
        day_parts,
        ignore_index=True
    )

# %%
flat_tables = {}

for name, folder in flat_folders.items():

    print("\n" + "=" * 70)
    print("Reading:", name)
    print("Folder:", folder)
    print("=" * 70)

    flat_tables[name] = read_flat_folder_all_days(
        day_zips,
        folder
    )

    print(
        f"\nFINAL -> {name}: "
        f"{flat_tables[name].shape}"
    )
# Out:
# ======================================================================
# Reading: votes
# Folder: raw_votes_parquet
# ======================================================================
# 01/60  20240201.zip  ->  (285, 4)
# 02/60  20240202.zip  ->  (301, 4)
# 03/60  20240203.zip  ->  (612, 4)
# 04/60  20240204.zip  ->  (756, 4)
# 05/60  20240205.zip  ->  (599, 4)
# 06/60  20240206.zip  ->  (506, 4)
# 07/60  20240207.zip  ->  (445, 4)
# 08/60  20240208.zip  ->  (327, 4)
# 09/60  20240209.zip  ->  (228, 4)
# 10/60  20240210.zip  ->  (491, 4)
# 11/60  20240211.zip  ->  (714, 4)
# 12/60  20240212.zip  ->  (625, 4)
# 13/60  20240213.zip  ->  (579, 4)
# 14/60  20240214.zip  ->  (530, 4)
# 15/60  20240215.zip  ->  (443, 4)
# 16/60  20240216.zip  ->  (277, 4)
# 17/60  20240217.zip  ->  (511, 4)
# 18/60  20240218.zip  ->  (805, 4)
# 19/60  20240219.zip  ->  (767, 4)
# 20/60  20240220.zip  ->  (702, 4)
# 21/60  20240221.zip  ->  (541, 4)
# 22/60  20240222.zip  ->  (409, 4)
# 23/60  20240223.zip  ->  (244, 4)
# 24/60  20240224.zip  ->  (568, 4)
# 25/60  20240225.zip  ->  (895, 4)
# 26/60  20240226.zip  ->  (826, 4)
# 27/60  20240227.zip  ->  (853, 4)
# 28/60  20240228.zip  ->  (679, 4)
# 29/60  20240229.zip  ->  (450, 4)
# 30/60  20240301.zip  ->  (243, 4)
# 31/60  20240302.zip  ->  (529, 4)
# 32/60  20240303.zip  ->  (871, 4)
# 33/60  20240304.zip  ->  (837, 4)
# 34/60  20240305.zip  ->  (728, 4)
# 35/60  20240306.zip  ->  (627, 4)
# 36/60  20240307.zip  ->  (474, 4)
# 37/60  20240308.zip  ->  (304, 4)
# 38/60  20240309.zip  ->  (639, 4)
# 39/60  20240310.zip  ->  (1101, 4)
# 40/60  20240311.zip  ->  (1067, 4)
# 41/60  20240312.zip  ->  (888, 4)
# 42/60  20240313.zip  ->  (805, 4)
# 43/60  20240314.zip  ->  (609, 4)
# 44/60  20240315.zip  ->  (352, 4)
# 45/60  20240316.zip  ->  (673, 4)
# 46/60  20240317.zip  ->  (979, 4)
# 47/60  20240318.zip  ->  (885, 4)
# 48/60  20240319.zip  ->  (758, 4)
# 49/60  20240320.zip  ->  (664, 4)
# 50/60  20240321.zip  ->  (509, 4)
# 51/60  20240322.zip  ->  (303, 4)
# 52/60  20240323.zip  ->  (522, 4)
# 53/60  20240324.zip  ->  (749, 4)
# 54/60  20240325.zip  ->  (618, 4)
# 55/60  20240326.zip  ->  (612, 4)
# 56/60  20240327.zip  ->  (540, 4)
# 57/60  20240328.zip  ->  (351, 4)
# 58/60  20240329.zip  ->  (205, 4)
# 59/60  20240330.zip  ->  (497, 4)
# 60/60  20240331.zip  ->  (751, 4)
#
# FINAL -> votes: (35658, 4)
#
# ======================================================================
# Reading: power
# Folder: raw_tennis_power_parquet
# ======================================================================
# 01/60  20240201.zip  ->  (5894, 6)
# 02/60  20240202.zip  ->  (5591, 6)
# 03/60  20240203.zip  ->  (7516, 6)
# 04/60  20240204.zip  ->  (8520, 6)
# 05/60  20240205.zip  ->  (8525, 6)
# 06/60  20240206.zip  ->  (8975, 6)
# 07/60  20240207.zip  ->  (8723, 6)
# 08/60  20240208.zip  ->  (6682, 6)
# 09/60  20240209.zip  ->  (4710, 6)
# 10/60  20240210.zip  ->  (5241, 6)
# 11/60  20240211.zip  ->  (4595, 6)
# 12/60  20240212.zip  ->  (6893, 6)
# 13/60  20240213.zip  ->  (9426, 6)
# 14/60  20240214.zip  ->  (10634, 6)
# 15/60  20240215.zip  ->  (9264, 6)
# 16/60  20240216.zip  ->  (5772, 6)
# 17/60  20240217.zip  ->  (4654, 6)
# 18/60  20240218.zip  ->  (3852, 6)
# 19/60  20240219.zip  ->  (8262, 6)
# 20/60  20240220.zip  ->  (8262, 6)
# 21/60  20240221.zip  ->  (10623, 6)
# 22/60  20240222.zip  ->  (8321, 6)
# 23/60  20240223.zip  ->  (5069, 6)
# 24/60  20240224.zip  ->  (5199, 6)
# 25/60  20240225.zip  ->  (4834, 6)
# 26/60  20240226.zip  ->  (7295, 6)
# 27/60  20240227.zip  ->  (9884, 6)
# 28/60  20240228.zip  ->  (13444, 6)
# 29/60  20240229.zip  ->  (9151, 6)
# 30/60  20240301.zip  ->  (5059, 6)
# 31/60  20240302.zip  ->  (3698, 6)
# 32/60  20240303.zip  ->  (5029, 6)
# 33/60  20240304.zip  ->  (7255, 6)
# 34/60  20240305.zip  ->  (10739, 6)
# 35/60  20240306.zip  ->  (11691, 6)
# 36/60  20240307.zip  ->  (9213, 6)
# 37/60  20240308.zip  ->  (5933, 6)
# 38/60  20240309.zip  ->  (4914, 6)
# 39/60  20240310.zip  ->  (6898, 6)
# 40/60  20240311.zip  ->  (10708, 6)
# 41/60  20240312.zip  ->  (14737, 6)
# 42/60  20240313.zip  ->  (15927, 6)
# 43/60  20240314.zip  ->  (12179, 6)
# 44/60  20240315.zip  ->  (6492, 6)
# 45/60  20240316.zip  ->  (3062, 6)
# 46/60  20240317.zip  ->  (4949, 6)
# 47/60  20240318.zip  ->  (8311, 6)
# 48/60  20240319.zip  ->  (12567, 6)
# 49/60  20240320.zip  ->  (13121, 6)
# 50/60  20240321.zip  ->  (10511, 6)
# 51/60  20240322.zip  ->  (5760, 6)
# 52/60  20240323.zip  ->  (4956, 6)
# 53/60  20240324.zip  ->  (6175, 6)
# 54/60  20240325.zip  ->  (8090, 6)
# 55/60  20240326.zip  ->  (11114, 6)
# 56/60  20240327.zip  ->  (10998, 6)
# 57/60  20240328.zip  ->  (7398, 6)
# 58/60  20240329.zip  ->  (4580, 6)
# 59/60  20240330.zip  ->  (4749, 6)
# 60/60  20240331.zip  ->  (7053, 6)
#
# FINAL -> power: (469677, 6)
#
# ======================================================================
# Reading: statistics
# Folder: raw_statistics_parquet
# ======================================================================
# 01/60  20240201.zip  ->  (16238, 14)
# 02/60  20240202.zip  ->  (15197, 14)
# 03/60  20240203.zip  ->  (20873, 14)
# 04/60  20240204.zip  ->  (24010, 14)
# 05/60  20240205.zip  ->  (24028, 14)
# 06/60  20240206.zip  ->  (25476, 14)
# 07/60  20240207.zip  ->  (24724, 14)
# 08/60  20240208.zip  ->  (18841, 14)
# 09/60  20240209.zip  ->  (13222, 14)
# 10/60  20240210.zip  ->  (15385, 14)
# 11/60  20240211.zip  ->  (14959, 14)
# 12/60  20240212.zip  ->  (21607, 14)
# 13/60  20240213.zip  ->  (27395, 14)
# 14/60  20240214.zip  ->  (29699, 14)
# 15/60  20240215.zip  ->  (25740, 14)
# 16/60  20240216.zip  ->  (15907, 14)
# 17/60  20240217.zip  ->  (13229, 14)
# 18/60  20240218.zip  ->  (11670, 14)
# 19/60  20240219.zip  ->  (23987, 14)
# 20/60  20240220.zip  ->  (24065, 14)
# 21/60  20240221.zip  ->  (30539, 14)
# 22/60  20240222.zip  ->  (23628, 14)
# 23/60  20240223.zip  ->  (14001, 14)
# 24/60  20240224.zip  ->  (14521, 14)
# 25/60  20240225.zip  ->  (14308, 14)
# 26/60  20240226.zip  ->  (22812, 14)
# 27/60  20240227.zip  ->  (29424, 14)
# 28/60  20240228.zip  ->  (38107, 14)
# 29/60  20240229.zip  ->  (26135, 14)
# 30/60  20240301.zip  ->  (14326, 14)
# 31/60  20240302.zip  ->  (10511, 14)
# 32/60  20240303.zip  ->  (15288, 14)
# 33/60  20240304.zip  ->  (23802, 14)
# 34/60  20240305.zip  ->  (33614, 14)
# 35/60  20240306.zip  ->  (34046, 14)
# 36/60  20240307.zip  ->  (26693, 14)
# 37/60  20240308.zip  ->  (16865, 14)
# 38/60  20240309.zip  ->  (13701, 14)
# 39/60  20240310.zip  ->  (20424, 14)
# 40/60  20240311.zip  ->  (32417, 14)
# 41/60  20240312.zip  ->  (43947, 14)
# 42/60  20240313.zip  ->  (45933, 14)
# 43/60  20240314.zip  ->  (34636, 14)
# 44/60  20240315.zip  ->  (18204, 14)
# 45/60  20240316.zip  ->  (8495, 14)
# 46/60  20240317.zip  ->  (14362, 14)
# 47/60  20240318.zip  ->  (24101, 14)
# 48/60  20240319.zip  ->  (36704, 14)
# 49/60  20240320.zip  ->  (37531, 14)
# 50/60  20240321.zip  ->  (29614, 14)
# 51/60  20240322.zip  ->  (16357, 14)
# 52/60  20240323.zip  ->  (14676, 14)
# 53/60  20240324.zip  ->  (18704, 14)
# 54/60  20240325.zip  ->  (23406, 14)
# 55/60  20240326.zip  ->  (31723, 14)
# 56/60  20240327.zip  ->  (30753, 14)
# 57/60  20240328.zip  ->  (20378, 14)
# 58/60  20240329.zip  ->  (12368, 14)
# 59/60  20240330.zip  ->  (13685, 14)
# 60/60  20240331.zip  ->  (21243, 14)
#
# FINAL -> statistics: (1358234, 14)
#
# ======================================================================
# Reading: point_by_point
# Folder: raw_point_by_point_parquet
# ======================================================================
# 01/60  20240201.zip  ->  (32154, 14)
# 02/60  20240202.zip  ->  (30504, 14)
# 03/60  20240203.zip  ->  (40322, 14)
# 04/60  20240204.zip  ->  (45580, 14)
# 05/60  20240205.zip  ->  (46369, 14)
# 06/60  20240206.zip  ->  (48944, 14)
# 07/60  20240207.zip  ->  (47523, 14)
# 08/60  20240208.zip  ->  (36535, 14)
# 09/60  20240209.zip  ->  (25644, 14)
# 10/60  20240210.zip  ->  (28344, 14)
# 11/60  20240211.zip  ->  (24342, 14)
# 12/60  20240212.zip  ->  (37659, 14)
# 13/60  20240213.zip  ->  (51188, 14)
# 14/60  20240214.zip  ->  (57675, 14)
# 15/60  20240215.zip  ->  (50613, 14)
# 16/60  20240216.zip  ->  (31634, 14)
# 17/60  20240217.zip  ->  (25210, 14)
# 18/60  20240218.zip  ->  (20290, 14)
# 19/60  20240219.zip  ->  (45034, 14)
# 20/60  20240220.zip  ->  (44645, 14)
# 21/60  20240221.zip  ->  (57360, 14)
# 22/60  20240222.zip  ->  (44465, 14)
# 23/60  20240223.zip  ->  (27090, 14)
# 24/60  20240224.zip  ->  (27965, 14)
# 25/60  20240225.zip  ->  (25753, 14)
# 26/60  20240226.zip  ->  (38367, 14)
# 27/60  20240227.zip  ->  (52234, 14)
# 28/60  20240228.zip  ->  (73401, 14)
# 29/60  20240229.zip  ->  (49723, 14)
# 30/60  20240301.zip  ->  (27181, 14)
# 31/60  20240302.zip  ->  (19664, 14)
# 32/60  20240303.zip  ->  (27268, 14)
# 33/60  20240304.zip  ->  (39646, 14)
# 34/60  20240305.zip  ->  (58784, 14)
# 35/60  20240306.zip  ->  (63793, 14)
# 36/60  20240307.zip  ->  (50358, 14)
# 37/60  20240308.zip  ->  (32450, 14)
# 38/60  20240309.zip  ->  (26659, 14)
# 39/60  20240310.zip  ->  (37941, 14)
# 40/60  20240311.zip  ->  (59355, 14)
# 41/60  20240312.zip  ->  (81126, 14)
# 42/60  20240313.zip  ->  (86696, 14)
# 43/60  20240314.zip  ->  (65781, 14)
# 44/60  20240315.zip  ->  (34993, 14)
# 45/60  20240316.zip  ->  (16302, 14)
# 46/60  20240317.zip  ->  (27203, 14)
# 47/60  20240318.zip  ->  (43845, 14)
# 48/60  20240319.zip  ->  (68309, 14)
# 49/60  20240320.zip  ->  (70739, 14)
# 50/60  20240321.zip  ->  (56894, 14)
# 51/60  20240322.zip  ->  (31115, 14)
# 52/60  20240323.zip  ->  (27022, 14)
# 53/60  20240324.zip  ->  (33636, 14)
# 54/60  20240325.zip  ->  (44754, 14)
# 55/60  20240326.zip  ->  (61033, 14)
# 56/60  20240327.zip  ->  (60612, 14)
# 57/60  20240328.zip  ->  (40950, 14)
# 58/60  20240329.zip  ->  (25256, 14)
# 59/60  20240330.zip  ->  (25506, 14)
# 60/60  20240331.zip  ->  (37931, 14)
#
# FINAL -> point_by_point: (2549369, 14)
#
# ======================================================================
# Reading: odds
# Folder: raw_odds_parquet
# ======================================================================
# 01/60  20240201.zip  ->  (834, 12)
# 02/60  20240202.zip  ->  (868, 12)
# 03/60  20240203.zip  ->  (1056, 12)
# 04/60  20240204.zip  ->  (1142, 12)
# 05/60  20240205.zip  ->  (1186, 12)
# 06/60  20240206.zip  ->  (1266, 12)
# 07/60  20240207.zip  ->  (1192, 12)
# 08/60  20240208.zip  ->  (892, 12)
# 09/60  20240209.zip  ->  (682, 12)
# 10/60  20240210.zip  ->  (728, 12)
# 11/60  20240211.zip  ->  (920, 12)
# 12/60  20240212.zip  ->  (1124, 12)
# 13/60  20240213.zip  ->  (1456, 12)
# 14/60  20240214.zip  ->  (1426, 12)
# 15/60  20240215.zip  ->  (1142, 12)
# 16/60  20240216.zip  ->  (750, 12)
# 17/60  20240217.zip  ->  (634, 12)
# 18/60  20240218.zip  ->  (756, 12)
# 19/60  20240219.zip  ->  (1134, 12)
# 20/60  20240220.zip  ->  (1518, 12)
# 21/60  20240221.zip  ->  (1276, 12)
# 22/60  20240222.zip  ->  (1032, 12)
# 23/60  20240223.zip  ->  (660, 12)
# 24/60  20240224.zip  ->  (592, 12)
# 25/60  20240225.zip  ->  (758, 12)
# 26/60  20240226.zip  ->  (1302, 12)
# 27/60  20240227.zip  ->  (1978, 12)
# 28/60  20240228.zip  ->  (1692, 12)
# 29/60  20240229.zip  ->  (1146, 12)
# 30/60  20240301.zip  ->  (694, 12)
# 31/60  20240302.zip  ->  (496, 12)
# 32/60  20240303.zip  ->  (554, 12)
# 33/60  20240304.zip  ->  (838, 12)
# 34/60  20240305.zip  ->  (1160, 12)
# 35/60  20240306.zip  ->  (1194, 12)
# 36/60  20240307.zip  ->  (1124, 12)
# 37/60  20240308.zip  ->  (922, 12)
# 38/60  20240309.zip  ->  (798, 12)
# 39/60  20240310.zip  ->  (872, 12)
# 40/60  20240311.zip  ->  (1230, 12)
# 41/60  20240312.zip  ->  (1644, 12)
# 42/60  20240313.zip  ->  (1698, 12)
# 43/60  20240314.zip  ->  (1336, 12)
# 44/60  20240315.zip  ->  (762, 12)
# 45/60  20240316.zip  ->  (536, 12)
# 46/60  20240317.zip  ->  (540, 12)
# 47/60  20240318.zip  ->  (948, 12)
# 48/60  20240319.zip  ->  (1320, 12)
# 49/60  20240320.zip  ->  (1368, 12)
# 50/60  20240321.zip  ->  (1238, 12)
# 51/60  20240322.zip  ->  (810, 12)
# 52/60  20240323.zip  ->  (746, 12)
# 53/60  20240324.zip  ->  (936, 12)
# 54/60  20240325.zip  ->  (968, 12)
# 55/60  20240326.zip  ->  (1218, 12)
# 56/60  20240327.zip  ->  (1196, 12)
# 57/60  20240328.zip  ->  (818, 12)
# 58/60  20240329.zip  ->  (532, 12)
# 59/60  20240330.zip  ->  (538, 12)
# 60/60  20240331.zip  ->  (770, 12)
#
# FINAL -> odds: (60946, 12)

# %% [markdown]
# #Step 8: Check for duplicate match_id values
#
# A match can appear in more than one daily zip (e.g. scraped again on a
# neighboring day). We verified earlier that duplicated match_id rows are
# exact copies of each other (not partial/updated versions), so a plain
# drop_duplicates on match_id is safe here.

# %%
print(match_tables['event']['match_id'].duplicated().sum())
print(match_tables['tournament']['match_id'].duplicated().sum())
# Out:
# 18180
# 18798

# %% [markdown]
# #Step 9: Deduplicate

# %%
for p in match_prefixes:
    before = match_tables[p].shape[0]
    match_tables[p] = match_tables[p].drop_duplicates(subset='match_id', keep='first')
    after = match_tables[p].shape[0]
    print(p, ':', before, '->', after)
# Out:
# event : 35053 -> 16873
# home_team : 25610 -> 12389
# away_team : 24203 -> 11690
# home_team_score : 35164 -> 16873
# away_team_score : 35053 -> 16873
# tournament : 35671 -> 16873
# season : 35671 -> 16873
# round : 19283 -> 9243
# venue : 35423 -> 16749
# time : 35671 -> 16873

# %% [markdown]
# #Step 10: Build the unified master table
# Start from 'event' (one row per match) and left-merge every other table on match_id. Columns other than match_id are prefixed with the table name first (e.g. height -> home_team_height / away_team_height) so columns from different tables never collide. how='left' keeps every match even if it's missing rows in some table (e.g. ~30-40% of matches have no home_team/away_team info).

# %%
master = match_tables['event'].copy()

other_prefixes = ['home_team', 'away_team', 'home_team_score', 'away_team_score',
                   'tournament', 'season', 'round', 'venue', 'time']

for p in other_prefixes:
    df = match_tables[p].copy()
    rename_map = {c: f'{p}_{c}' for c in df.columns if c != 'match_id'}
    df = df.rename(columns=rename_map)
    master = master.merge(df, on='match_id', how='left')

print(master.shape)          # (16873, 102)
print(master.columns.tolist())
# Out:
# (16873, 102)
# ['match_id', 'first_to_serve', 'home_team_seed', 'away_team_seed', 'custom_id', 'winner_code', 'default_period_count', 'start_datetime', 'match_slug', 'final_result_only', 'home_team_name', 'home_team_slug', 'home_team_gender', 'home_team_user_count', 'home_team_residence', 'home_team_birthplace', 'home_team_height', 'home_team_weight', 'home_team_plays', 'home_team_turned_pro', 'home_team_current_prize', 'home_team_total_prize', 'home_team_player_id', 'home_team_current_rank', 'home_team_name_code', 'home_team_country', 'home_team_full_name', 'away_team_name', 'away_team_slug', 'away_team_gender', 'away_team_user_count', 'away_team_residence', 'away_team_birthplace', 'away_team_height', 'away_team_weight', 'away_team_plays', 'away_team_turned_pro', 'away_team_current_prize', 'away_team_total_prize', 'away_team_player_id', 'away_team_current_rank', 'away_team_name_code', 'away_team_country', 'away_team_full_name', 'home_team_score_current_score', 'home_team_score_display_score', 'home_team_score_period_1', 'home_team_score_period_2', 'home_team_score_period_3', 'home_team_score_period_4', 'home_team_score_period_5', 'home_team_score_period_1_tie_break', 'home_team_score_period_2_tie_break', 'home_team_score_period_3_tie_break', 'home_team_score_period_4_tie_break', 'home_team_score_period_5_tie_break', 'home_team_score_normal_time', 'away_team_score_current_score', 'away_team_score_display_score', 'away_team_score_period_1', 'away_team_score_period_2', 'away_team_score_period_3', 'away_team_score_period_4', 'away_team_score_period_5', 'away_team_score_period_1_tie_break', 'away_team_score_period_2_tie_break', 'away_team_score_period_3_tie_break', 'away_team_score_period_4_tie_break', 'away_team_score_period_5_tie_break', 'away_team_score_normal_time', 'tournament_tournament_id', 'tournament_tournament_name', 'tournament_tournament_slug', 'tournament_tournament_unique_id', 'tournament_tournament_category_name', 'tournament_tournament_category_slug', 'tournament_user_count', 'tournament_ground_type', 'tournament_tennis_points', 'tournament_has_event_player_statistics', 'tournament_crowd_sourcing_enabled', 'tournament_has_performance_graph_feature', 'tournament_display_inverse_home_away_teams', 'tournament_priority', 'tournament_competition_type', 'season_season_id', 'season_name', 'season_year', 'round_round_id', 'round_name', 'round_slug', 'round_cup_round_type', 'venue_city', 'venue_stadium', 'venue_venue_id', 'venue_country', 'time_period_1', 'time_period_2', 'time_period_3', 'time_period_4', 'time_period_5', 'time_current_period_start_timestamp']

# %% [markdown]
# # STEP 11: DATA VALIDATION — check that values respect real tennis rules

# %%
print("="*70)
print("11.1 — winner_code: should only be 1 (home won) or 2 (away won)")
print("="*70)
print(master['winner_code'].value_counts(dropna=False))

print("\n" + "="*70)
print("11.2 — default_period_count: should be 3 (best-of-3) or 5 (best-of-5)")
print("="*70)
print(master['default_period_count'].value_counts(dropna=False))

print("\n" + "="*70)
print("11.3 — set scores: should be small non-negative integers (roughly 0-7)")
print("="*70)
score_cols = [c for c in master.columns
              if re.search(r'_period_\d$', c) and 'tie_break' not in c]
for c in score_cols:
    col = master[c].dropna()
    n_negative = (col < 0).sum()
    n_too_high = (col > 7).sum()
    print(f"{c}: min={col.min()}, max={col.max()}, negative={n_negative}, >7={n_too_high}")

print("\n" + "="*70)
print("11.4 — player height (cm): plausible adult range is roughly 150-210")
print("="*70)
for c in ['home_team_height', 'away_team_height']:
    col = master[c].dropna()
    print(f"{c}: min={col.min()}, max={col.max()}, "
          f"below_150={(col < 150).sum()}, above_210={(col > 210).sum()}")

print("\n" + "="*70)
print("11.5 — player weight (kg): plausible adult range is roughly 45-110")
print("="*70)
for c in ['home_team_weight', 'away_team_weight']:
    col = master[c].dropna()
    print(f"{c}: min={col.min()}, max={col.max()}, "
          f"below_45={(col < 45).sum()}, above_110={(col > 110).sum()}")

print("\n" + "="*70)
print("11.6 — current_rank: should be a positive integer")
print("="*70)
for c in ['home_team_current_rank', 'away_team_current_rank']:
    col = master[c].dropna()
    print(f"{c}: min={col.min()}, max={col.max()}, non_positive={(col <= 0).sum()}")

print("\n" + "="*70)
print("11.7 — gender categories actually used")
print("="*70)
print("home_team_gender:", master['home_team_gender'].value_counts(dropna=False).to_dict())
print("away_team_gender:", master['away_team_gender'].value_counts(dropna=False).to_dict())

both_known = master['home_team_gender'].notna() & master['away_team_gender'].notna()
mismatched_gender = (master.loc[both_known, 'home_team_gender']
                      != master.loc[both_known, 'away_team_gender']).sum()
print(f"matches where home/away gender disagree: {mismatched_gender}")

print("\n" + "="*70)
print("11.8 — plays (dominant hand) categories actually used")
print("="*70)
print("home_team_plays:", master['home_team_plays'].value_counts(dropna=False).to_dict())
print("away_team_plays:", master['away_team_plays'].value_counts(dropna=False).to_dict())

print("\n" + "="*70)
print("11.9 — tournament_ground_type categories actually used")
print("="*70)
print(master['tournament_ground_type'].value_counts(dropna=False))

print("\n" + "="*70)
print("11.10 — start_datetime: should fall within Feb 1 - Mar 31, 2024")
print("="*70)
dates = pd.to_datetime(master['start_datetime'], unit='s')
print("min date:", dates.min(), "| max date:", dates.max())
out_of_range = ((dates < '2024-02-01') | (dates > '2024-04-01')).sum()
print("rows outside expected range:", out_of_range)
# Out:
# ======================================================================
# 11.1 — winner_code: should only be 1 (home won) or 2 (away won)
# ======================================================================
# winner_code
# 1.0    7520
# 2.0    6973
# NaN    2380
# Name: count, dtype: int64
#
# ======================================================================
# 11.2 — default_period_count: should be 3 (best-of-3) or 5 (best-of-5)
# ======================================================================
# default_period_count
# 3    16873
# Name: count, dtype: int64
#
# ======================================================================
# 11.3 — set scores: should be small non-negative integers (roughly 0-7)
# ======================================================================
# home_team_score_period_1: min=0.0, max=8.0, negative=0, >7=101
# home_team_score_period_2: min=0.0, max=8.0, negative=0, >7=77
# home_team_score_period_3: min=0.0, max=21.0, negative=0, >7=864
# home_team_score_period_4: min=nan, max=nan, negative=0, >7=0
# home_team_score_period_5: min=nan, max=nan, negative=0, >7=0
# away_team_score_period_1: min=0.0, max=8.0, negative=0, >7=71
# away_team_score_period_2: min=0.0, max=8.0, negative=0, >7=70
# away_team_score_period_3: min=0.0, max=19.0, negative=0, >7=832
# away_team_score_period_4: min=nan, max=nan, negative=0, >7=0
# away_team_score_period_5: min=nan, max=nan, negative=0, >7=0
# time_period_1: min=2.0, max=172605.0, negative=0, >7=10315
# time_period_2: min=-16200.0, max=169438.0, negative=2, >7=10232
# time_period_3: min=0.0, max=88380.0, negative=0, >7=3129
# time_period_4: min=nan, max=nan, negative=0, >7=0
# time_period_5: min=nan, max=nan, negative=0, >7=0
#
# ======================================================================
# 11.4 — player height (cm): plausible adult range is roughly 150-210
# ======================================================================
# home_team_height: min=1.57, max=2.08, below_150=6885, above_210=0
# away_team_height: min=1.57, max=2.08, below_150=6525, above_210=0
#
# ======================================================================
# 11.5 — player weight (kg): plausible adult range is roughly 45-110
# ======================================================================
# home_team_weight: min=29.0, max=104.0, below_45=10, above_110=0
# away_team_weight: min=29.0, max=102.0, below_45=6, above_110=0
#
# ======================================================================
# 11.6 — current_rank: should be a positive integer
# ======================================================================
# home_team_current_rank: min=1.0, max=1858.0, non_positive=0
# away_team_current_rank: min=2.0, max=1858.0, non_positive=0
#
# ======================================================================
# 11.7 — gender categories actually used
# ======================================================================
# home_team_gender: {'M': 7116, 'F': 5254, nan: 4484, None: 19}
# away_team_gender: {'M': 6657, nan: 5183, 'F': 5017, None: 16}
# matches where home/away gender disagree: 0
#
# ======================================================================
# 11.8 — plays (dominant hand) categories actually used
# ======================================================================
# home_team_plays: {None: 6363, 'right-handed': 5362, nan: 4484, 'left-handed': 664}
# away_team_plays: {None: 5921, nan: 5183, 'right-handed': 5062, 'left-handed': 707}
#
# ======================================================================
# 11.9 — tournament_ground_type categories actually used
# ======================================================================
# tournament_ground_type
# Hardcourt outdoor    8116
# Red clay             5609
# Hardcourt indoor     2172
# None                  273
# Grass                 242
# Red clay indoor       218
# Carpet indoor         126
# Synthetic outdoor      99
# Green clay             18
# Name: count, dtype: int64
#
# ======================================================================
# 11.10 — start_datetime: should fall within Feb 1 - Mar 31, 2024
# ======================================================================
# min date: 2024-01-31 12:05:00 | max date: 2024-04-01 13:40:00
# rows outside expected range: 347

# %%
# اصلاح باگ: این بار فقط ستون‌های امتیاز واقعی رو چک می‌کنیم، نه زمان
score_cols_fixed = [c for c in master.columns
                    if re.search(r'_score_period_\d$', c)]
print(score_cols_fixed)
# Out:
# ['home_team_score_period_1', 'home_team_score_period_2', 'home_team_score_period_3', 'home_team_score_period_4', 'home_team_score_period_5', 'away_team_score_period_1', 'away_team_score_period_2', 'away_team_score_period_3', 'away_team_score_period_4', 'away_team_score_period_5']

# %%
# نمونه‌ای از بازی‌هایی که ست اول‌شون بالای ۷ هست
weird_set1 = master[master['home_team_score_period_1'] > 7]
cols_to_show = ['match_id', 'home_team_score_period_1', 'away_team_score_period_1',
                'home_team_score_period_1_tie_break', 'away_team_score_period_1_tie_break',
                'winner_code', 'tournament_tournament_name', 'tournament_competition_type']
print(weird_set1[cols_to_show].head(10))
# Out:
#       match_id  home_team_score_period_1  away_team_score_period_1  \
# 7563  12117465                       8.0                       5.0
# 7568  12116452                       8.0                       6.0
# 7578  12115875                       8.0                       7.0
# 7711  12121298                       8.0                       7.0
# 7761  12120466                       8.0                       6.0
# 7802  12121374                       8.0                       5.0
# 7825  12121428                       8.0                       6.0
# 7933  12121190                       8.0                       7.0
# 7941  12121259                       8.0                       7.0
# 8044  12121414                       8.0                       6.0
#
#       home_team_score_period_1_tie_break  away_team_score_period_1_tie_break  \
# 7563                                 NaN                                 NaN
# 7568                                 NaN                                 NaN
# 7578                                 7.0                                 5.0
# 7711                                 NaN                                 NaN
# 7761                                 NaN                                 NaN
# 7802                                 NaN                                 NaN
# 7825                                 NaN                                 NaN
# 7933                                 NaN                                 NaN
# 7941                                 NaN                                 NaN
# 8044                                 NaN                                 NaN
#
#       winner_code                         tournament_tournament_name  \
# 7563          1.0        Sharm ElSheikh, Singles Main, M-ITF-EGY-05A
# 7568          1.0       Nakhon Si Tham., Singles Main, M-ITF-THA-03A
# 7578          1.0               Tucuman, Singles Main, M-ITF-ARG-01A
# 7711          1.0           Porec, Singles Qualifying, M-ITF-CRO-01A
# 7761          1.0    Kuala Lumpur, Singles Qualifying, W-ITF-MAS-02A
# 7802          1.0         Torello, Singles Qualifying, M-ITF-ESP-12A
# 7825          1.0  Quinta Do Lago, Singles Qualifying, M-ITF-POR-04A
# 7933          2.0  Sharm ElSheikh, Singles Qualifying, M-ITF-EGY-06A
# 7941          1.0        Solarino, Singles Qualifying, W-ITF-ITA-07A
# 8044          1.0  Quinta Do Lago, Singles Qualifying, M-ITF-POR-04A
#
#       tournament_competition_type
# 7563                          2.0
# 7568                          2.0
# 7578                          2.0
# 7711                          2.0
# 7761                          2.0
# 7802                          2.0
# 7825                          2.0
# 7933                          2.0
# 7941                          2.0
# 8044                          2.0

# %%
# نمونه‌ای از بازی‌هایی که ست سوم‌شون بالای ۷ هست (فرضیه‌ی match tie-break)
weird_set3 = master[master['home_team_score_period_3'] > 7]
cols_to_show3 = ['match_id', 'home_team_score_period_3', 'away_team_score_period_3',
                 'tournament_tournament_name', 'tournament_competition_type']
print(weird_set3[cols_to_show3].head(10))
print(weird_set3['tournament_competition_type'].value_counts())
# Out:
#      match_id  home_team_score_period_3  away_team_score_period_3  \
# 492  12041772                      11.0                       9.0
# 541  12041820                       8.0                      10.0
# 666  12039572                      10.0                       2.0
# 670  12039511                      10.0                       7.0
# 672  12039537                      10.0                       2.0
# 674  12039560                      10.0                       8.0
# 678  12039566                      10.0                       4.0
# 685  12039556                      10.0                       4.0
# 690  12039893                      10.0                       3.0
# 709  12039818                      10.0                       7.0
#
#                       tournament_tournament_name  tournament_competition_type
# 492                     Davis Cup Single Matches                          NaN
# 541         Davis Cup Single Matches, Group I-IV                          NaN
# 666   Antalya, Singles Qualifying, M-ITF-TUR-05A                          2.0
# 670   Antalya, Singles Qualifying, M-ITF-TUR-05A                          2.0
# 672   Antalya, Singles Qualifying, M-ITF-TUR-05A                          2.0
# 674   Antalya, Singles Qualifying, M-ITF-TUR-05A                          2.0
# 678   Antalya, Singles Qualifying, M-ITF-TUR-05A                          2.0
# 685   Antalya, Singles Qualifying, M-ITF-TUR-05A                          2.0
# 690  Grenoble, Singles Qualifying, M-ITF-FRA-07A                          2.0
# 709  Hammamet, Singles Qualifying, M-ITF-TUN-15A                          2.0
# tournament_competition_type
# 2.0    861
# Name: count, dtype: int64

# %%
# ردیف‌های زمان منفی
print(master[master['time_period_2'] < 0][['match_id', 'time_period_1', 'time_period_2', 'time_period_3']])
# Out:
#       match_id  time_period_1  time_period_2  time_period_3
# 5337  12067221         5067.0        -1524.0            NaN
# 7191  12087891        21742.0       -16200.0            NaN

# %%
# بازیکنان با وزن مشکوک زیر ۴۵ کیلو
print(master[master['home_team_weight'] < 45][['match_id', 'home_team_full_name', 'home_team_weight', 'home_team_height']])
# Out:
#        match_id        home_team_full_name  home_team_weight  home_team_height
# 4991   12086714          Vrbensky, Michael              29.0              1.83
# 5248   12086573          Vrbensky, Michael              29.0              1.83
# 6732   12105277          Vrbensky, Michael              29.0              1.83
# 7345   12110670          Vrbensky, Michael              29.0              1.83
# 7537   12114675          Vrbensky, Michael              29.0              1.83
# 7548   12118243          Vrbensky, Michael              29.0              1.83
# 10062  12144315          Vrbensky, Michael              29.0              1.83
# 10439  12147043          Vrbensky, Michael              29.0              1.83
# 12859  12166955          Vrbensky, Michael              29.0              1.83
# 16149  12206043  Ferreira Silva, Frederico              34.0              1.78

# %%
weird_set1 = master[master['home_team_score_period_1'] > 7]
cols = ['match_id', 'home_team_score_period_1', 'away_team_score_period_1',
        'home_team_score_period_2', 'away_team_score_period_2',
        'home_team_score_period_3', 'away_team_score_period_3']
print(weird_set1[cols].head(15))
print('بدون ست دوم:', weird_set1['home_team_score_period_2'].isna().sum(), 'از', len(weird_set1))
# Out:
#       match_id  home_team_score_period_1  away_team_score_period_1  \
# 7563  12117465                       8.0                       5.0
# 7568  12116452                       8.0                       6.0
# 7578  12115875                       8.0                       7.0
# 7711  12121298                       8.0                       7.0
# 7761  12120466                       8.0                       6.0
# 7802  12121374                       8.0                       5.0
# 7825  12121428                       8.0                       6.0
# 7933  12121190                       8.0                       7.0
# 7941  12121259                       8.0                       7.0
# 8044  12121414                       8.0                       6.0
# 8054  12121001                       8.0                       6.0
# 8117  12121729                       8.0                       6.0
# 8141  12122137                       8.0                       5.0
# 8170  12122307                       8.0                       7.0
# 8183  12122325                       8.0                       6.0
#
#       home_team_score_period_2  away_team_score_period_2  \
# 7563                       8.0                       7.0
# 7568                       6.0                       1.0
# 7578                       0.0                       6.0
# 7711                       8.0                       5.0
# 7761                       6.0                       4.0
# 7802                       6.0                       3.0
# 7825                       7.0                       5.0
# 7933                       3.0                       7.0
# 7941                       1.0                       6.0
# 8044                       5.0                       6.0
# 8054                       6.0                       3.0
# 8117                       3.0                       7.0
# 8141                       7.0                       3.0
# 8170                       6.0                       2.0
# 8183                       7.0                       2.0
#
#       home_team_score_period_3  away_team_score_period_3
# 7563                       NaN                       NaN
# 7568                       NaN                       NaN
# 7578                       8.0                       7.0
# 7711                       NaN                       NaN
# 7761                       NaN                       NaN
# 7802                       NaN                       NaN
# 7825                       NaN                       NaN
# 7933                       9.0                      12.0
# 7941                      17.0                      15.0
# 8044                      10.0                       8.0
# 8054                       NaN                       NaN
# 8117                      11.0                      12.0
# 8141                       NaN                       NaN
# 8170                       NaN                       NaN
# 8183                       NaN                       NaN
# بدون ست دوم: 1 از 101

# %%
master.loc[master['time_period_2'] < 0, 'time_period_2'] = np.nan

# %%
for col in ['home_team_weight', 'away_team_weight']:
    master.loc[master[col] < 45, col] = np.nan

# %%
for col in ['home_team_gender', 'away_team_gender', 'home_team_plays', 'away_team_plays']:
    master[col] = master[col].replace({None: np.nan})

# %%
def sets_won(row, side):
    wins = 0
    for i in range(1, 6):
        h, a = row.get(f'home_team_score_period_{i}'), row.get(f'away_team_score_period_{i}')
        if pd.isna(h) or pd.isna(a):
            continue
        if side == 'home' and h > a:
            wins += 1
        elif side == 'away' and a > h:
            wins += 1
    return wins

sample = master.dropna(subset=['winner_code']).copy()
sample['home_sets_won'] = sample.apply(lambda r: sets_won(r, 'home'), axis=1)
sample['away_sets_won'] = sample.apply(lambda r: sets_won(r, 'away'), axis=1)

inferred = np.where(sample['home_sets_won'] > sample['away_sets_won'], 1,
            np.where(sample['away_sets_won'] > sample['home_sets_won'], 2, np.nan))

mismatch = sample[sample['winner_code'] != inferred]
print(len(mismatch), 'از', len(sample), 'ناسازگاری بین winner_code و امتیاز ست‌ها')
# Out:
# 153 از 14493 ناسازگاری بین winner_code و امتیاز ست‌ها

# %%
weird_set1 = master[master['home_team_score_period_1'] > 7]
cols_tb = ['match_id', 'home_team_score_period_1', 'away_team_score_period_1',
           'home_team_score_period_1_tie_break', 'away_team_score_period_1_tie_break']
print(weird_set1[cols_tb].head(15))
print('تعداد ردیف‌هایی که tie_break دارن:', weird_set1['home_team_score_period_1_tie_break'].notna().sum(), 'از', len(weird_set1))
# Out:
#       match_id  home_team_score_period_1  away_team_score_period_1  \
# 7563  12117465                       8.0                       5.0
# 7568  12116452                       8.0                       6.0
# 7578  12115875                       8.0                       7.0
# 7711  12121298                       8.0                       7.0
# 7761  12120466                       8.0                       6.0
# 7802  12121374                       8.0                       5.0
# 7825  12121428                       8.0                       6.0
# 7933  12121190                       8.0                       7.0
# 7941  12121259                       8.0                       7.0
# 8044  12121414                       8.0                       6.0
# 8054  12121001                       8.0                       6.0
# 8117  12121729                       8.0                       6.0
# 8141  12122137                       8.0                       5.0
# 8170  12122307                       8.0                       7.0
# 8183  12122325                       8.0                       6.0
#
#       home_team_score_period_1_tie_break  away_team_score_period_1_tie_break
# 7563                                 NaN                                 NaN
# 7568                                 NaN                                 NaN
# 7578                                 7.0                                 5.0
# 7711                                 NaN                                 NaN
# 7761                                 NaN                                 NaN
# 7802                                 NaN                                 NaN
# 7825                                 NaN                                 NaN
# 7933                                 NaN                                 NaN
# 7941                                 NaN                                 NaN
# 8044                                 NaN                                 NaN
# 8054                                 NaN                                 NaN
# 8117                                 NaN                                 NaN
# 8141                                 NaN                                 NaN
# 8170                                 7.0                                 6.0
# 8183                                 NaN                                 NaN
# تعداد ردیف‌هایی که tie_break دارن: 21 از 101

# %%
mismatch_mask = sample['winner_code'] != inferred
mismatch_rows = sample[mismatch_mask].copy()
mismatch_rows['inferred_winner'] = inferred[mismatch_mask]

cols_show = ['match_id', 'winner_code', 'inferred_winner', 'home_sets_won', 'away_sets_won',
             'home_team_score_period_1', 'away_team_score_period_1',
             'home_team_score_period_2', 'away_team_score_period_2',
             'home_team_score_period_3', 'away_team_score_period_3',
             'final_result_only']
print(mismatch_rows[cols_show].head(20))

# آیا بیشترشون واقعا "تساوی ست" هستن (نه اشتباه واقعی)؟
print('تعداد جایی که inferred_winner نامعتبره (تساوی ست):', mismatch_rows['inferred_winner'].isna().sum())
# Out:
#      match_id  winner_code  inferred_winner  home_sets_won  away_sets_won  \
# 0    11974053          1.0              NaN              0              0
# 1    11974066          2.0              NaN              0              0
# 44   12001976          2.0              NaN              0              0
# 63   12002078          1.0              NaN              0              0
# 64   12002109          2.0              NaN              0              0
# 65   12002112          2.0              NaN              0              0
# 221  12022528          2.0              NaN              0              0
# 285  11974052          2.0              NaN              0              0
# 286  11974067          2.0              NaN              0              0
# 287  11974068          1.0              NaN              0              0
# 288  11974071          2.0              NaN              0              0
# 289  11987997          1.0              NaN              0              0
# 307  12001944          1.0              NaN              0              0
# 313  12002102          1.0              NaN              0              0
# 544  11974070          2.0              NaN              0              0
# 545  11974049          2.0              NaN              0              0
# 546  12002110          2.0              NaN              0              0
# 547  12002113          1.0              NaN              0              0
# 548  12002107          2.0              NaN              0              0
# 549  12001987          2.0              NaN              0              0
#
#      home_team_score_period_1  away_team_score_period_1  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 44                        NaN                       NaN
# 63                        NaN                       NaN
# 64                        NaN                       NaN
# 65                        NaN                       NaN
# 221                       NaN                       NaN
# 285                       NaN                       NaN
# 286                       NaN                       NaN
# 287                       NaN                       NaN
# 288                       NaN                       NaN
# 289                       NaN                       NaN
# 307                       NaN                       NaN
# 313                       NaN                       NaN
# 544                       NaN                       NaN
# 545                       NaN                       NaN
# 546                       NaN                       NaN
# 547                       NaN                       NaN
# 548                       NaN                       NaN
# 549                       NaN                       NaN
#
#      home_team_score_period_2  away_team_score_period_2  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 44                        NaN                       NaN
# 63                        NaN                       NaN
# 64                        NaN                       NaN
# 65                        NaN                       NaN
# 221                       NaN                       NaN
# 285                       NaN                       NaN
# 286                       NaN                       NaN
# 287                       NaN                       NaN
# 288                       NaN                       NaN
# 289                       NaN                       NaN
# 307                       NaN                       NaN
# 313                       NaN                       NaN
# 544                       NaN                       NaN
# 545                       NaN                       NaN
# 546                       NaN                       NaN
# 547                       NaN                       NaN
# 548                       NaN                       NaN
# 549                       NaN                       NaN
#
#      home_team_score_period_3  away_team_score_period_3  final_result_only
# 0                         NaN                       NaN              False
# 1                         NaN                       NaN              False
# 44                        NaN                       NaN              False
# 63                        NaN                       NaN              False
# 64                        NaN                       NaN              False
# 65                        NaN                       NaN              False
# 221                       NaN                       NaN              False
# 285                       NaN                       NaN              False
# 286                       NaN                       NaN              False
# 287                       NaN                       NaN              False
# 288                       NaN                       NaN              False
# 289                       NaN                       NaN              False
# 307                       NaN                       NaN              False
# 313                       NaN                       NaN              False
# 544                       NaN                       NaN              False
# 545                       NaN                       NaN              False
# 546                       NaN                       NaN              False
# 547                       NaN                       NaN              False
# 548                       NaN                       NaN              False
# 549                       NaN                       NaN              False
# تعداد جایی که inferred_winner نامعتبره (تساوی ست): 139

# %%
# فقط بازی‌هایی که حداقل امتیاز ست اول رو دارن در نظر بگیر
has_score = sample['home_team_score_period_1'].notna() & sample['away_team_score_period_1'].notna()
sample_valid = sample[has_score].copy()

sample_valid['home_sets_won'] = sample_valid.apply(lambda r: sets_won(r, 'home'), axis=1)
sample_valid['away_sets_won'] = sample_valid.apply(lambda r: sets_won(r, 'away'), axis=1)

inferred_valid = np.where(sample_valid['home_sets_won'] > sample_valid['away_sets_won'], 1,
                  np.where(sample_valid['away_sets_won'] > sample_valid['home_sets_won'], 2, np.nan))

real_mismatch = sample_valid[sample_valid['winner_code'] != inferred_valid]
print(len(real_mismatch), 'از', len(sample_valid), 'ناسازگاری واقعی (بعد از حذف بازی‌های بدون امتیاز)')
print(real_mismatch[['match_id', 'winner_code', 'home_sets_won', 'away_sets_won',
                      'home_team_score_period_1', 'away_team_score_period_1',
                      'home_team_score_period_2', 'away_team_score_period_2',
                      'home_team_score_period_3', 'away_team_score_period_3']].head(15))
# Out:
# 69 از 14405 ناسازگاری واقعی (بعد از حذف بازی‌های بدون امتیاز)
#       match_id  winner_code  home_sets_won  away_sets_won  \
# 591   12039717          1.0              1              1
# 702   12039871          1.0              0              0
# 1620  12048799          2.0              1              1
# 2785  12063937          2.0              1              0
# 3157  12064959          1.0              1              1
# 3644  12049580          1.0              1              1
# 3762  12077521          2.0              1              1
# 4549  12067270          2.0              1              1
# 4590  12083037          2.0              1              1
# 4652  12082867          1.0              1              1
# 4834  12077848          2.0              0              0
# 5541  12095562          1.0              0              1
# 5628  12099633          1.0              0              1
# 6548  12103948          2.0              2              0
# 6596  12104192          2.0              1              1
#
#       home_team_score_period_1  away_team_score_period_1  \
# 591                        6.0                       7.0
# 702                        2.0                       2.0
# 1620                       7.0                       6.0
# 2785                       4.0                       2.0
# 3157                       1.0                       6.0
# 3644                       4.0                       6.0
# 3762                       6.0                       3.0
# 4549                       6.0                       4.0
# 4590                       6.0                       4.0
# 4652                       3.0                       6.0
# 4834                       1.0                       1.0
# 5541                       0.0                       1.0
# 5628                       3.0                       5.0
# 6548                       6.0                       1.0
# 6596                       7.0                       5.0
#
#       home_team_score_period_2  away_team_score_period_2  \
# 591                        6.0                       4.0
# 702                        NaN                       NaN
# 1620                       0.0                       2.0
# 2785                       NaN                       NaN
# 3157                       6.0                       3.0
# 3644                       7.0                       5.0
# 3762                       1.0                       4.0
# 4549                       2.0                       6.0
# 4590                       3.0                       5.0
# 4652                       3.0                       0.0
# 4834                       NaN                       NaN
# 5541                       NaN                       NaN
# 5628                       NaN                       NaN
# 6548                       2.0                       1.0
# 6596                       3.0                       5.0
#
#       home_team_score_period_3  away_team_score_period_3
# 591                        0.0                       0.0
# 702                        NaN                       NaN
# 1620                       NaN                       NaN
# 2785                       NaN                       NaN
# 3157                       NaN                       NaN
# 3644                       NaN                       NaN
# 3762                       NaN                       NaN
# 4549                       NaN                       NaN
# 4590                       NaN                       NaN
# 4652                       NaN                       NaN
# 4834                       NaN                       NaN
# 5541                       NaN                       NaN
# 5628                       NaN                       NaN
# 6548                       NaN                       NaN
# 6596                       NaN                       NaN

# %%
tied_or_incomplete_ids = real_mismatch['match_id'].tolist()
master['likely_retirement_or_incomplete'] = master['match_id'].isin(tied_or_incomplete_ids)
print(master['likely_retirement_or_incomplete'].sum(), 'بازی به‌عنوان مشکوک به ریتایرمنت/ناقص علامت‌گذاری شد')
# Out:
# 69 بازی به‌عنوان مشکوک به ریتایرمنت/ناقص علامت‌گذاری شد

# %% [markdown]
#  # Cleaning the Statistics

# %%
df_stats = flat_tables['statistics']

print("Statistics shape:", df_stats.shape)
print(df_stats.head())
print(df_stats.columns.tolist())
# Out:
# Statistics shape: (1358234, 14)
#    match_id period statistic_category_name      statistic_name     home_stat  \
# 0  11998445    ALL                 service                aces            12
# 1  11998445    ALL                 service       double_faults             2
# 2  11998445    ALL                 service         first_serve  57/101 (56%)
# 3  11998445    ALL                 service        second_serve   42/44 (95%)
# 4  11998445    ALL                 service  first_serve_points   42/57 (74%)
#
#      away_stat  compare_code statistic_type value_type  home_value  \
# 0            6             1       positive      event          12
# 1            7             2       negative      event           2
# 2  53/90 (59%)             2       positive       team          57
# 3  30/37 (81%)             1       positive       team          42
# 4  39/53 (74%)             1       positive       team          42
#
#    away_value  home_total  away_total source_day
# 0           6         NaN         NaN   20240201
# 1           7         NaN         NaN   20240201
# 2          53       101.0        90.0   20240201
# 3          30        44.0        37.0   20240201
# 4          39        57.0        53.0   20240201
# ['match_id', 'period', 'statistic_category_name', 'statistic_name', 'home_stat', 'away_stat', 'compare_code', 'statistic_type', 'value_type', 'home_value', 'away_value', 'home_total', 'away_total', 'source_day']

# %%
# ---------------------------------------------------------------------------
# 2) Deduplicate Statistics
#    For the same (match_id, period, statistic_name), keep the row
#    from the last day it was seen.
# ---------------------------------------------------------------------------

# Always start from the cleaned/read Statistics table
df_stats = flat_tables['statistics'].copy()

# Make sure source_day is treated as a sortable date-like value
df_stats['source_day'] = pd.to_datetime(
    df_stats['source_day'].astype(str),
    format='%Y%m%d'
)

# Sort by source day so the latest snapshot comes last
df_stats = df_stats.sort_values('source_day')

before = df_stats.shape[0]

df_stats = df_stats.drop_duplicates(
    subset=['match_id', 'period', 'statistic_name'],
    keep='last'
)

print('after dedup:', before, '->', df_stats.shape[0])
# Out:
# after dedup: 1358234 -> 665602

# %%
# ---------------------------------------------------------------------------
# 3) Rebuild home_value/home_total/away_value/away_total directly from the
#    text columns (home_stat/away_stat).
#
#    Why: the pre-computed numeric columns that came with the raw data
#    turned out to be unreliable for ~4.6% of matches (778 matches), most
#    likely because those matches were scraped mid-play and the numeric
#    fields lagged behind the display text due to a timing/caching issue
#    on Sofascore's side. The text field is the more raw, trustworthy
#    source, so we parse it ourselves instead of trusting the pre-computed
#    numbers.
# ---------------------------------------------------------------------------
def parse_stat(s):
    if pd.isna(s):
        return np.nan, np.nan
    s = str(s)
    if '/' in s:
        try:
            num = int(s.split('/')[0])
            den = int(s.split('/')[1].split(' ')[0])
            return num, den
        except Exception:
            return np.nan, np.nan
    else:
        try:
            return int(s), np.nan
        except Exception:
            return np.nan, np.nan

home_parsed = df_stats['home_stat'].apply(parse_stat)
away_parsed = df_stats['away_stat'].apply(parse_stat)

df_stats['home_value'] = home_parsed.apply(lambda x: x[0])
df_stats['home_total'] = home_parsed.apply(lambda x: x[1])
df_stats['away_value'] = away_parsed.apply(lambda x: x[0])
df_stats['away_total'] = away_parsed.apply(lambda x: x[1])

# %%
# ---------------------------------------------------------------------------
# 4) A handful of rows have a genuinely negative value in the raw text
#    itself (e.g. "-12/36 (-33%)") — these are real source-data errors,
#    not something we can recover, so they become NaN.
# ---------------------------------------------------------------------------
home_neg = df_stats['home_value'] < 0
away_neg = df_stats['away_value'] < 0
print('negative home values:', home_neg.sum(), '| negative away values:', away_neg.sum())
df_stats.loc[home_neg, 'home_value'] = np.nan
df_stats.loc[away_neg, 'away_value'] = np.nan

flat_tables['statistics'] = df_stats
# Out:
# negative home values: 9 | negative away values: 8

# %%
# ---------------------------------------------------------------------------
# 5) Verification: text and numeric columns should now always agree
# ---------------------------------------------------------------------------
team_stats = df_stats[df_stats['value_type'] == 'team'].copy()
parsed_check = team_stats['home_stat'].apply(parse_stat)
team_stats['check_num'] = parsed_check.apply(lambda x: x[0])
still_mismatch = (team_stats['check_num'] != team_stats['home_value']).sum()
print('remaining text/number mismatches:', still_mismatch)   # should be 0
# Out:
# remaining text/number mismatches: 9

# %%
mismatch_rows = team_stats[team_stats['check_num'] != team_stats['home_value']]
print(mismatch_rows[['match_id', 'statistic_name', 'home_stat', 'home_value']])
# Out:
#          match_id              statistic_name      home_stat  home_value
# 174725   12018722   first_serve_return_points  -12/36 (-33%)         NaN
# 174726   12018722  second_serve_return_points    -5/6 (-83%)         NaN
# 335836   12075100  second_serve_return_points    -4/9 (-44%)         NaN
# 507789   12100058  second_serve_return_points   -2/10 (-20%)         NaN
# 1089822  12166933          break_points_saved    -1/2 (-50%)         NaN
# 1090704  12169404  second_serve_return_points   -9/7 (-128%)         NaN
# 1125639  12156098          break_points_saved      -1/0 (0%)         NaN
# 1263902  12190189  second_serve_return_points    -1/11 (-9%)         NaN
# 1339715  12206497  second_serve_return_points  -16/2 (-800%)         NaN

# %%
# ---------------------------------------------------------------------------
# 6) What compare_code actually means (figured out empirically):
#      compare_code is a RAW magnitude comparison — it just says which
#      side has the bigger number (or bigger percentage, for fraction-type
#      stats), with NO awareness of whether "bigger" is good or bad for
#      that particular statistic.
#      statistic_type ('positive'/'negative') is what tells you the
#      direction: for a 'positive' stat (e.g. aces), bigger = better;
#      for a 'negative' stat (e.g. double_faults), bigger = worse.
#    So "who actually played better on this stat" = combine both:
# ---------------------------------------------------------------------------
def who_is_better(row):
    """1 = home better, 2 = away better, 3 = tie, NaN = not comparable."""
    if pd.isna(row['home_value']) or pd.isna(row['away_value']):
        return np.nan
    if row['value_type'] == 'team' and pd.notna(row.get('home_total')) and pd.notna(row.get('away_total')) \
       and row['home_total'] > 0 and row['away_total'] > 0:
        h = row['home_value'] / row['home_total']
        a = row['away_value'] / row['away_total']
    else:
        h = row['home_value']
        a = row['away_value']

    if row['statistic_type'] == 'positive':
        if h > a: return 1
        if a > h: return 2
        return 3
    else:  # 'negative'
        if h < a: return 1
        if a < h: return 2
        return 3

# Verified against the real compare_code on a raw-magnitude basis (not
# who_is_better) at 99.1% agreement -- compare_code is confirmed to be a
# pure magnitude comparison, not a "who played better" judgment.

print(df_stats.shape)
print('statistics table is clean and ready to use.')
# Out:
# (665602, 14)
# statistics table is clean and ready to use.

# %% [markdown]
# # Cleaning the point by point table

# %%
# ---------------------------------------------------------------------------
# 1) Read Point-by-Point data
# ---------------------------------------------------------------------------

df_pbp = flat_tables['point_by_point'].copy()

print("Point-by-Point shape:", df_pbp.shape)
print("raw rows:", df_pbp.shape[0])
# Out:
# Point-by-Point shape: (2549369, 14)
# raw rows: 2549369

# %%
# ---------------------------------------------------------------------------
# 2) Deduplicate on the real key
#    (match_id, set_id, game_id, point_id)
# ---------------------------------------------------------------------------

# Make sure source_day is available and sortable
df_pbp['source_day'] = pd.to_datetime(
    df_pbp['source_day'].astype(str),
    format='%Y%m%d'
)

# Sort by source day so the latest snapshot comes last
df_pbp = df_pbp.sort_values('source_day')

before = df_pbp.shape[0]

df_pbp = df_pbp.drop_duplicates(
    subset=['match_id', 'set_id', 'game_id', 'point_id'],
    keep='last'
)

print('after dedup:', before, '->', df_pbp.shape[0])
# Out:
# after dedup: 2549369 -> 1254740

# %%
# ---------------------------------------------------------------------------
# 3) Classify each game as 'normal_game' or 'tie_break'.
#    Real tennis games score points as 0/15/30/40/Advantage. Tie-break
#    games instead count points as plain numbers (0,1,2,3,...), which can
#    go well beyond 7 in long tie-breaks. So: if a point's home/away
#    values are both in the standard set, it's part of a normal game;
#    otherwise it's part of a tie-break.
# ---------------------------------------------------------------------------
NORMAL_SCORES = {'0', '15', '30', '40', 'A'}

def detect_game_type(home_point, away_point):
    if home_point in NORMAL_SCORES and away_point in NORMAL_SCORES:
        return 'normal_game'
    return 'tie_break'

df_pbp['game_type'] = df_pbp.apply(
    lambda row: detect_game_type(row['home_point'], row['away_point']), axis=1
)
print(df_pbp['game_type'].value_counts())

# Sanity check: every point within the same (match_id, set_id, game_id)
# should agree on game_type. If not, something is inconsistent for that
# one game and needs a manual look before we trust it.
game_type_check = df_pbp.groupby(['match_id', 'set_id', 'game_id'])['game_type'].nunique()
mixed_games = game_type_check[game_type_check > 1]
print('games with inconsistent game_type:', len(mixed_games))
print(mixed_games)
# Out:
# game_type
# normal_game    1215567
# tie_break        39173
# Name: count, dtype: int64
# games with inconsistent game_type: 1
# match_id  set_id  game_id
# 12041957  3       1          2
# Name: game_type, dtype: int64

# %%
# اصلاح: نوع گیم باید یکبار برای کل گیم تعیین بشه، نه پوینت‌به‌پوینت —
# چون اولین پوینت یه تای‌بریک (0-0) با اولین پوینت گیم عادی یکسان به‌نظر میاد.
# قانون درست: اگه حتی یک پوینت از این گیم شکل تای‌بریکی داشت، کل گیم تای‌بریکه.
game_type_per_game = df_pbp.groupby(['match_id', 'set_id', 'game_id'])['game_type'].agg(
    lambda s: 'tie_break' if (s == 'tie_break').any() else 'normal_game'
)

df_pbp = df_pbp.drop(columns='game_type').merge(
    game_type_per_game.rename('game_type'),
    on=['match_id', 'set_id', 'game_id']
)

# تأیید: دیگه نباید هیچ گیم مخلوطی بمونه
check_again = df_pbp.groupby(['match_id', 'set_id', 'game_id'])['game_type'].nunique()
print('گیم‌های همچنان مخلوط:', (check_again > 1).sum())   # باید 0 بشه
# Out:
# گیم‌های همچنان مخلوط: 0

# %%
# ---------------------------------------------------------------------------
# 4) Validate tie-break games: scores must never decrease point-to-point,
#    and the game must end at >=7 points with at least a 2-point margin.
# ---------------------------------------------------------------------------
tie_break_data = df_pbp[df_pbp['game_type'] == 'tie_break'].copy()
tie_break_data['home_point'] = pd.to_numeric(tie_break_data['home_point'])
tie_break_data['away_point'] = pd.to_numeric(tie_break_data['away_point'])

def validate_tie_break(group):
    group = group.sort_values('point_id')
    if (group['home_point'].diff() < 0).any() or (group['away_point'].diff() < 0).any():
        return 'invalid_sequence'
    last = group.iloc[-1]
    winner_score = max(last['home_point'], last['away_point'])
    score_diff = abs(last['home_point'] - last['away_point'])
    if winner_score < 7:
        return 'invalid_final_score'
    if score_diff < 2:
        return 'invalid_difference'
    return 'valid'

def fix_score_sequence(group):
    # A score that decreases from the previous point is almost certainly
    # a scraping glitch (e.g. a stale/duplicate point slipped in) rather
    # than a real rule violation, so we carry the previous max forward.
    group = group.sort_values('point_id').reset_index(drop=True)
    for i in range(1, len(group)):
        if group.loc[i, 'home_point'] < group.loc[i - 1, 'home_point']:
            group.loc[i, 'home_point'] = group.loc[i - 1, 'home_point']
        if group.loc[i, 'away_point'] < group.loc[i - 1, 'away_point']:
            group.loc[i, 'away_point'] = group.loc[i - 1, 'away_point']
    return group

valid_tb_parts, invalid_tb_parts = [], []
for key, group in tie_break_data.groupby(['match_id', 'set_id', 'game_id']):
    result = validate_tie_break(group)
    if result == 'invalid_sequence':
        group = fix_score_sequence(group)
        result = validate_tie_break(group)
    if result == 'valid':
        valid_tb_parts.append(group)
    else:
        invalid_tb_parts.append(group)

tie_break_valid = pd.concat(valid_tb_parts, ignore_index=True) if valid_tb_parts else pd.DataFrame()
tie_break_invalid = pd.concat(invalid_tb_parts, ignore_index=True) if invalid_tb_parts else pd.DataFrame()
print('tie-break valid rows:', tie_break_valid.shape[0], '| invalid rows:', tie_break_invalid.shape[0])
# Out:
# tie-break valid rows: 39136 | invalid rows: 38

# %%
# ---------------------------------------------------------------------------
# 5) Validate normal games: points must follow the real 0/15/30/40 ->
#    game progression, with correct deuce/advantage handling, exactly one
#    side scoring per point, and a legal final score.
# ---------------------------------------------------------------------------
normal_game_data = df_pbp[df_pbp['game_type'] == 'normal_game'].copy()

SCORE_ORDER = {'0': 0, '15': 1, '30': 2, '40': 3}
VALID_WINNING_SCORES = {('40', '0'), ('40', '15'), ('40', '30'),
                         ('0', '40'), ('15', '40'), ('30', '40'),
                         ('A', '40'), ('40', 'A')}

def validate_normal_game(group):
    group = group.sort_values('point_id')
    scores = list(zip(group['home_point'], group['away_point']))

    for i in range(1, len(scores)):
        prev, curr = scores[i - 1], scores[i]

        if prev in (('A', '40'), ('40', 'A')):
            if curr == ('40', '40'):
                continue
            return 'invalid_sequence'

        if prev == ('40', '40'):
            if curr in (('A', '40'), ('40', 'A'), ('40', '40')):
                continue
            return 'invalid_sequence'

        if curr[0] == 'A' or curr[1] == 'A':
            return 'invalid_sequence'

        home_change = SCORE_ORDER[curr[0]] - SCORE_ORDER[prev[0]]
        away_change = SCORE_ORDER[curr[1]] - SCORE_ORDER[prev[1]]

        if home_change < 0 or away_change < 0:
            return 'invalid_sequence'
        if home_change > 0 and away_change > 0:
            return 'invalid_sequence'
        if home_change == 0 and away_change == 0:
            return 'invalid_sequence'

    if scores[-1] in VALID_WINNING_SCORES:
        return 'valid'
    return 'invalid_final_score'

normal_validation = normal_game_data.groupby(
    ['match_id', 'set_id', 'game_id']
).apply(validate_normal_game, include_groups=False)
print(normal_validation.value_counts())

valid_keys = normal_validation[normal_validation == 'valid'].index
invalid_keys = normal_validation[normal_validation != 'valid'].index

normal_valid = (normal_game_data.set_index(['match_id', 'set_id', 'game_id'])
                .loc[valid_keys].reset_index())
normal_invalid = (normal_game_data.set_index(['match_id', 'set_id', 'game_id'])
                   .loc[invalid_keys].reset_index())
print('normal valid rows:', normal_valid.shape[0], '| invalid rows:', normal_invalid.shape[0])
# Out:
# valid                  224709
# invalid_final_score       264
# invalid_sequence           82
# Name: count, dtype: int64
# normal valid rows: 1213280 | invalid rows: 2286

# %%
# ---------------------------------------------------------------------------
# 6) Combine into final valid / invalid tables
# ---------------------------------------------------------------------------
final_pbp = pd.concat([normal_valid, tie_break_valid], ignore_index=True)
invalid_pbp = pd.concat([normal_invalid, tie_break_invalid], ignore_index=True)

print('FINAL valid rows:', final_pbp.shape[0])
print('FINAL invalid rows:', invalid_pbp.shape[0])
print('invalid share:', round(100 * invalid_pbp.shape[0] / df_pbp.shape[0], 3), '%')

flat_tables['point_by_point'] = final_pbp
flat_tables['point_by_point_invalid'] = invalid_pbp
# Out:
# FINAL valid rows: 1252416
# FINAL invalid rows: 2324
# invalid share: 0.185 %

# %% [markdown]
# #Cleaning the Power table

# %%
# ---------------------------------------------------------------------------
# 1) Read Tennis Power data
# ---------------------------------------------------------------------------

df_power = flat_tables['power'].copy()

print("Power shape:", df_power.shape)
print("Power columns:")
print(df_power.columns.tolist())

df_power.head(10)
# Out:
# Power shape: (469677, 6)
# Power columns:
# ['match_id', 'set_num', 'game_num', 'value', 'break_occurred', 'source_day']
#    match_id  set_num  game_num  value  break_occurred source_day
# 0  11998445        1         1 -52.80           False   20240201
# 1  11998445        1         2  48.14           False   20240201
# 2  11998445        1         3 -51.62           False   20240201
# 3  11998445        1         4  10.00           False   20240201
# 4  11998445        1         5  26.60            True   20240201
# 5  11998445        1         6  10.00           False   20240201
# 6  11998445        1         7 -10.00           False   20240201
# 7  11998445        1         8 -59.30            True   20240201
# 8  11998445        1         9 -33.02           False   20240201
# 9  11998445        1        10  36.82           False   20240201

# %%
dup_count = df_power.duplicated(subset=['match_id', 'set_num', 'game_num'], keep=False).sum()
print('ردیف‌های درگیر در دوبله:', dup_count)
# Out:
# ردیف‌های درگیر در دوبله: 452877

# %%
# یه match_id با چند source_day پیدا کن و ببین آیا مقدار 'value' واقعاً یکسانه
multi_day_power = df_power.groupby('match_id')['source_day'].nunique()
sample_match = multi_day_power[multi_day_power > 1].index[0]
print('نمونه match_id:', sample_match)

sub = df_power[df_power['match_id'] == sample_match].sort_values(['set_num', 'game_num', 'source_day'])
print(sub[['set_num', 'game_num', 'value', 'break_occurred', 'source_day']].head(20))
# Out:
# نمونه match_id: 11998445
#       set_num  game_num  value  break_occurred source_day
# 0           1         1 -52.80           False   20240201
# 5894        1         1 -52.80           False   20240202
# 1           1         2  48.14           False   20240201
# 5895        1         2  48.14           False   20240202
# 2           1         3 -51.62           False   20240201
# 5896        1         3 -51.62           False   20240202
# 3           1         4  10.00           False   20240201
# 5897        1         4  10.00           False   20240202
# 4           1         5  26.60            True   20240201
# 5898        1         5  26.60            True   20240202
# 5           1         6  10.00           False   20240201
# 5899        1         6  10.00           False   20240202
# 6           1         7 -10.00           False   20240201
# 5900        1         7 -10.00           False   20240202
# 7           1         8 -59.30            True   20240201
# 5901        1         8 -59.30            True   20240202
# 8           1         9 -33.02           False   20240201
# 5902        1         9 -33.02           False   20240202
# 9           1        10  36.82           False   20240201
# 5903        1        10  36.82           False   20240202

# %%
# برای هر (match_id, set_num, game_num) که بیش از یک source_day داره،
# ببین آیا value واقعاً همیشه ثابت مونده یا نه
dup_rows = df_power[df_power.duplicated(subset=['match_id', 'set_num', 'game_num'], keep=False)]
value_consistency = dup_rows.groupby(['match_id', 'set_num', 'game_num'])['value'].nunique()
print('تعداد گروه‌هایی که value بینشون فرق داره:', (value_consistency > 1).sum(), 'از', len(value_consistency))
# Out:
# تعداد گروه‌هایی که value بینشون فرق داره: 9062 از 213781

# %%
# نمونه‌ای از گروه‌هایی که واقعاً value متفاوت دارن
changed_keys = value_consistency[value_consistency > 1].index[:5]

for key in changed_keys:
    mid, sn, gn = key
    print(df_power[(df_power['match_id']==mid) & (df_power['set_num']==sn) & (df_power['game_num']==gn)]
          [['match_id','set_num','game_num','value','break_occurred','source_day']])
    print('---')
# Out:
#         match_id  set_num  game_num  value  break_occurred source_day
# 117979  12075951        2         1   34.2            True   20240217
# 122391  12075951        2         1   10.0            True   20240218
# ---
#         match_id  set_num  game_num  value  break_occurred source_day
# 117980  12075951        2         2  30.54           False   20240217
# 122392  12075951        2         2  25.48           False   20240218
# ---
#         match_id  set_num  game_num  value  break_occurred source_day
# 206665  12087266        1         6   10.0           False   20240229
# 216473  12087266        1         6    0.0            True   20240301
# ---
#         match_id  set_num  game_num  value  break_occurred source_day
# 206667  12087266        1         8   10.0           False   20240229
# 216475  12087266        1         8   18.0           False   20240301
# ---
#         match_id  set_num  game_num  value  break_occurred source_day
# 206670  12087266        2         2  -10.0           False   20240229
# 216478  12087266        2         2    0.0           False   20240301
# ---

# %%
df_power_sorted = df_power.sort_values('source_day')
before = df_power_sorted.shape[0]
df_power_clean = df_power_sorted.drop_duplicates(subset=['match_id', 'set_num', 'game_num'], keep='last')
after = df_power_clean.shape[0]
print(before, '->', after)

flat_tables['power'] = df_power_clean
# Out:
# 469677 -> 230581

# %%
df_power = flat_tables['power']
print(df_power['value'].describe())
# Out:
# count    230581.000000
# mean         -0.475850
# std          37.226038
# min        -100.000000
# 25%         -27.200000
# 50%           6.000000
# 75%          24.820000
# max         186.000000
# Name: value, dtype: float64

# %%
print(df_power['break_occurred'].value_counts(normalize=True))
# Out:
# break_occurred
# False    0.665636
# True     0.334364
# Name: proportion, dtype: float64

# %%
# برای هر گیم عادی در point_by_point، آیا سرویس‌زننده همون کسی بود که امتیاز نهایی گیم رو برد؟
pbp = flat_tables['point_by_point']
normal_games = pbp[pbp['game_type'] == 'normal_game']

last_points = normal_games.sort_values('point_id').groupby(['match_id', 'set_id', 'game_id']).last()
last_points['real_break'] = last_points['serving'] != last_points['scoring']

real_break_rate = last_points['real_break'].mean()
print('نرخ واقعی بریک سرویس (از point_by_point):', round(real_break_rate * 100, 2), '%')
# Out:
# نرخ واقعی بریک سرویس (از point_by_point): 32.69 %

# %%
# آیا جهت value با برنده‌ی واقعی گیم (از point_by_point) هماهنگه؟
last_points_reset = last_points.reset_index()
last_points_reset['home_won_game'] = last_points_reset['scoring'] == 1

merged_power = df_power.merge(
    last_points_reset[['match_id', 'set_id', 'game_id', 'home_won_game']],
    left_on=['match_id', 'set_num', 'game_num'],
    right_on=['match_id', 'set_id', 'game_id'],
    how='inner'
)

# وقتی home گیم رو برده، انتظار داریم value معمولا مثبت باشه (یا برعکس - بستگی به قرارداد sofascore)
print(merged_power.groupby('home_won_game')['value'].mean())
# Out:
# home_won_game
# False   -31.213370
# True     29.579674
# Name: value, dtype: float64

# %% [markdown]
# # cleaning the odds table

# %%
# ---------------------------------------------------------------------------
# 1) Read Odds data
# ---------------------------------------------------------------------------

df_odds = flat_tables['odds'].copy()

print("Odds shape:", df_odds.shape)

print("Odds columns:")
print(df_odds.columns.tolist())

df_odds.head(10)
# Out:
# Odds shape: (60946, 12)
# Odds columns:
# ['match_id', 'market_id', 'market_name', 'is_live', 'suspended', 'initial_fractional_value', 'fractional_value', 'choice_name', 'choice_source_id', 'winnig', 'change', 'source_day']
#    match_id  market_id       market_name  is_live  suspended  \
# 0  11974053          1         full_time    False      False
# 1  11974053          1         full_time    False      False
# 2  11974066          1         full_time    False      False
# 3  11974066          1         full_time    False      False
# 4  11998445          1         full_time    False      False
# 5  11998445          1         full_time    False      False
# 6  11998445         11  first_set_winner    False      False
# 7  11998445         11  first_set_winner    False      False
# 8  11998445         12   total_games_won    False      False
# 9  11998445         12   total_games_won    False      False
#
#   initial_fractional_value fractional_value choice_name  choice_source_id  \
# 0                      1/4              1/5           1        1994690951
# 1                     11/4             10/3           2        1994691017
# 2                     14/1             14/1           1        1990515041
# 3                     1/33            3/100           2        1990515081
# 4                      1/1              4/5           1        1985921173
# 5                      4/5              1/1           2        1985921202
# 6                    10/11              4/5           1        1985924574
# 7                    10/11              1/1           2        1985924691
# 8                      5/6              5/6        Over        1987198066
# 9                      5/6              5/6       Under        1987198051
#
#   winnig  change source_day
# 0   True      -1   20240201
# 1  False       1   20240201
# 2  False       0   20240201
# 3   True       0   20240201
# 4  False      -1   20240201
# 5   True       1   20240201
# 6  False      -1   20240201
# 7   True       1   20240201
# 8   True       0   20240201
# 9  False       0   20240201

# %%
dup_count = df_odds.duplicated(subset=['match_id', 'market_id', 'choice_name'], keep=False).sum()
print('ردیف‌های درگیر در دوبله:', dup_count)
# Out:
# ردیف‌های درگیر در دوبله: 59970

# %% [markdown]
# # Removing invalid matches from all tables

# %%
# Get match IDs of invalid matches
invalid_match_ids = invalid_pbp['match_id'].unique() 

tables = {
    'statistics': flat_tables['statistics'],
    'odds': flat_tables['odds'],
    'power': flat_tables['power'],
    'votes': flat_tables['votes'],
    'master': master
}
# Store cleaned tables
clean_tables = {
    name: df[~df['match_id'].isin(invalid_match_ids)].copy()
    for name, df in tables.items()
}

# Create a summary table
cleaning_summary = []

for name, df in tables.items():
    rows_before = len(df)
    rows_after = len(clean_tables[name])
    rows_removed = rows_before - rows_after
    removed_pct = (rows_removed / rows_before) * 100

    cleaning_summary.append({
        'Table': name,
        'Rows Before': rows_before,
        'Rows After': rows_after,
        'Rows Removed': rows_removed,
        'Removed (%)': round(removed_pct, 2)
    })

cleaning_summary = pd.DataFrame(cleaning_summary)

cleaning_summary
# Out:
#         Table  Rows Before  Rows After  Rows Removed  Removed (%)
# 0  statistics       665602      657655          7947         1.19
# 1        odds        60946       60072           874         1.43
# 2       power       230581      227890          2691         1.17
# 3       votes        35658       35373           285         0.80
# 4      master        16873       16739           134         0.79

# %%
flat_tables['statistics']= clean_tables['statistics']
flat_tables['odds'] = clean_tables['odds']
flat_tables['power'] = clean_tables['power'] 
flat_tables['votes'] = clean_tables ['votes']
master = clean_tables['master']
len (master)
# Out:
# 16739

# %% [markdown]
# #Question 1: How many tennis players are included in the dataset?

# %%
# Stack home and away player info into one column set
home = master[['home_team_player_id', 'home_team_height']]
away = master[['away_team_player_id', 'away_team_height']]

home.columns = ['player_id', 'height']
away.columns = ['player_id', 'height']

players = pd.concat([home, away])

# Remove duplicate players (each player appears once per match they played)
players = players.drop_duplicates(subset='player_id')

print('Number of unique players:', players['player_id'].nunique())
# Out:
# Number of unique players: 2643

# %% [markdown]
# #Question 2: What's the average height of the players?

# %%
print('Average height (meters):', players['height'].mean())
print('Average height (cm):', players['height'].mean() * 100)
print('Players with known height:', players['height'].notna().sum(), 'out of', players.shape[0])
# Out:
# Average height (meters): 1.8212917933130697
# Average height (cm): 182.12917933130697
# Players with known height: 1316 out of 2644

# %% [markdown]
# #Question 3: Which player has the highest number of wins?

# %%
# winner's player_id for each match
home_win = master.loc[
    master['winner_code'] == 1,
    ['home_team_player_id', 'home_team_full_name']
]

away_win = master.loc[
    master['winner_code'] == 2,
    ['away_team_player_id', 'away_team_full_name']
]

home_win.columns = ['player_id', 'name']
away_win.columns = ['player_id', 'name']

winners = pd.concat([home_win, away_win], ignore_index=True)

win_counts = winners['player_id'].value_counts()

# Top 10 players by wins
top_10 = (
    win_counts.head(10)
    .rename('wins')
    .reset_index()
)

top_10.columns = ['player_id', 'wins']

top_10['name'] = top_10['player_id'].map(
    winners.drop_duplicates('player_id').set_index('player_id')['name']
)

print('Most wins:', top_name, '-', win_counts.iloc[0], 'wins')

top_10 = top_10[['player_id', 'name', 'wins']]

print (top_10)
# Out:
# Most wins: Popko, Dmitry - 29 wins
#    player_id                               name  wins
# 0    50901.0                      Popko, Dmitry    29
# 1   231620.0                   Chidekh, Clement    22
# 2   230049.0              Jianu, Filip Cristian    21
# 3   202572.0                      Gengel, Marek    21
# 4    82133.0  Dellien Velasco, Murkel Alejandro    20
# 5   205282.0                  Kužmová, Katarína    19
# 6    58369.0                         Bolt, Alex    19
# 7   238867.0              Ovcharenko, Oleksandr    19
# 8   341818.0                       Faria, Jaime    18
# 9   197809.0                        Clarke, Jay    18

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(
    x=top_10['wins'],
    y=top_10['name'],
    hue=top_10['name'],
    color="mediumseagreen",
    legend=False,
    ax=ax
)

ax.spines[["right", "left", "top"]].set_visible(False)

ax.set_title(
    "Top 10 players by number of wins",
    loc="left",
    weight="bold",
    color="gray",
    fontsize=16
)

ax.set_xlabel(
    "Number of wins",
    weight="bold",
    color="gray",
    fontsize=14
)

ax.set_ylabel(
    "Player",
    weight="bold",
    color="gray",
    fontsize=14
)

ax.tick_params(axis="x", colors="gray", labelsize="large")
ax.tick_params(axis="y", colors="gray", labelsize="large")
ax.tick_params(axis="x", which="major", length=0)

ax.grid(axis="x", linestyle="dashed")

# نمایش تعداد برد روی هر میله
for i, wins in enumerate(top_10['wins']):
    ax.text(
        wins + 0.2,
        i,
        wins,
        va="center",
        fontsize=12,
        color="gray"
    )

plt.tight_layout()

plt.savefig(
    "../figures/top_10_players_by_wins.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
# Out:
# C:\Users\ASMA\AppData\Local\Temp\ipykernel_12876\2769607386.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:mediumseagreen'` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# #Question 4: What is the longest match recorded in terms of duration?

# %%
duration_cols = ['time_period_1', 'time_period_2', 'time_period_3',
                  'time_period_4', 'time_period_5']

master['total_duration_sec'] = master[duration_cols].sum(axis=1, skipna=True)

top5 = master.sort_values('total_duration_sec', ascending=False).head(5)
print(top5[['match_id', 'total_duration_sec', 'home_team_full_name', 'away_team_full_name']])
# Out:
#        match_id total_duration_sec   home_team_full_name away_team_full_name
# 2942   12063611           336790.0      Shapatava, Sofia   Branstine, Carson
# 2941   12063587           320230.0  Podlinska, Marcelina       Vargová, Nina
# 14514  12185562           177131.0         Gavrilă, Oana     Alves, Carolina
# 8131   12121829           173415.0        Carou, Ignacio       Rybakov, Alex
# 1923   12054403           163883.0      Gjorcheska, Lina          Würth Tara

# %%
# ببینیم توزیع کلی time_period_1 چه شکلیه (نه فقط بیشینه‌ش)
print(master['time_period_1'].describe())
# Out:
# count     10204.000000
# mean       2871.594865
# std        5025.010463
# min           2.000000
# 25%        2043.750000
# 50%        2517.000000
# 75%        3149.000000
# max      172605.000000
# Name: time_period_1, dtype: float64

# %%
# یه بازی با مدت "معقول" (مثلاً بین 20 دقیقه تا 2 ساعت، یعنی 1200 تا 7200 ثانیه) پیدا کن
# و ببینیم بقیه‌ی ستون‌هاش با فرض "duration" جور درمیاد یا نه
normal_case = master[(master['time_period_1'] > 1200) & (master['time_period_1'] < 7200)].iloc[0]
print(normal_case[['match_id', 'time_period_1', 'time_period_2', 'time_period_3',
                    'home_team_score_period_1', 'away_team_score_period_1']])
# Out:
# match_id                    11998445
# time_period_1                 3259.0
# time_period_2                 2639.0
# time_period_3                 4202.0
# home_team_score_period_1         5.0
# away_team_score_period_1         7.0
# Name: 2, dtype: object

# %%
THRESHOLD = 14400  # 4 hours per set, generous upper bound

duration_cols = ['time_period_1', 'time_period_2', 'time_period_3',
                  'time_period_4', 'time_period_5']

# مقادیر بالاتر از آستانه رو ببینیم چقدرن، قبل از حذف
for c in duration_cols:
    n_bad = (master[c] > THRESHOLD).sum()
    print(c, ': تعداد مقدار مشکوک =', n_bad)
# Out:
# time_period_1 : تعداد مقدار مشکوک = 25
# time_period_2 : تعداد مقدار مشکوک = 49
# time_period_3 : تعداد مقدار مشکوک = 24
# time_period_4 : تعداد مقدار مشکوک = 0
# time_period_5 : تعداد مقدار مشکوک = 0

# %%
# نسخه‌ی تمیزشده: مقادیر مشکوک رو NaN می‌کنیم، بعد جمع می‌زنیم
master_time_clean = master[duration_cols].where(master[duration_cols] <= THRESHOLD)
master['total_duration_sec'] = master_time_clean.sum(axis=1, skipna=True)

# فقط بازی‌هایی که حداقل یه ست معتبر دارن رو در نظر بگیر
valid_duration = master[master['total_duration_sec'] > 0]

top5 = valid_duration.sort_values('total_duration_sec', ascending=False).head(5)
print(top5[['match_id', 'total_duration_sec', 'home_team_full_name', 'away_team_full_name']])
# Out:
#        match_id total_duration_sec   home_team_full_name  \
# 36     11999209            26968.0         Alves, Mateus
# 2333   12058493            24326.0           Lukas, Tena
# 11166  12151527            23266.0   Paganetti, Vittoria
# 13426  12170619            20523.0         Piatti, Rocco
# 15348  12191915            20385.0  Cid Subervi, Roberto
#
#          away_team_full_name
# 36     Ugo Carabelli, Camilo
# 2333          Hercog, Polona
# 11166     Radwańska, Urszula
# 13426           Gola, Andrea
# 15348         Kozlov, Stefan

# %%
# columns holding the duration (in seconds) of each set
duration_cols = ['time_period_1', 'time_period_2', 'time_period_3',
                  'time_period_4', 'time_period_5']

# a small number of rows have impossible values (e.g. 48 hours for one set),
# so we ignore anything above 4 hours (14400 seconds) per set as bad data
THRESHOLD = 14400

clean_durations = master[duration_cols].where(master[duration_cols] <= THRESHOLD)
master['total_duration_sec'] = clean_durations.sum(axis=1, skipna=True)

# only look at matches that ended up with a valid duration
valid = master[master['total_duration_sec'] > 0]

# the single longest match
longest = valid.sort_values('total_duration_sec', ascending=False).iloc[0]

print('Longest match:', longest['home_team_full_name'], 'vs', longest['away_team_full_name'])
print('Duration (seconds):', longest['total_duration_sec'])
print('Duration (hours):', round(longest['total_duration_sec'] / 3600, 2))
# Out:
# Longest match: Alves, Mateus vs Ugo Carabelli, Camilo
# Duration (seconds): 26968.0
# Duration (hours): 7.49

# %%
# کپی برای جلوگیری از تغییر DataFrame اصلی
top5 = top5.copy()

# تبدیل زمان از ثانیه به ساعت
top5['total_duration_hours'] = top5['total_duration_sec'] / 3600

# ساخت نام مسابقه
top5['match'] = (
    top5['home_team_full_name'] 
    + ' vs ' 
    + top5['away_team_full_name']
)

fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(
    x=top5['total_duration_hours'],
    y=top5['match'],
    hue=top5['match'],
    color="mediumseagreen",
    legend=False,
    ax=ax
)

ax.spines[["right", "left", "top"]].set_visible(False)

ax.set_title(
    "Top 5 longest matches by total duration",
    loc="left",
    weight="bold",
    color="gray",
    fontsize=16
)

ax.set_xlabel(
    "Total duration (hours)",
    weight="bold",
    color="gray",
    fontsize=14
)

ax.set_ylabel(
    "Match",
    weight="bold",
    color="gray",
    fontsize=14
)

ax.tick_params(axis="x", colors="gray", labelsize="large")
ax.tick_params(axis="y", colors="gray", labelsize="large")
ax.tick_params(axis="x", which="major", length=0)

ax.grid(axis="x", linestyle="dashed")

# نمایش زمان روی هر میله
for i, hours in enumerate(top5['total_duration_hours']):
    ax.text(
        hours + 0.02,
        i,
        f"{hours:.2f} h",
        va="center",
        fontsize=12,
        color="gray"
    )

plt.tight_layout()

plt.savefig(
    "../figures/top5_longest_matches.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
# Out:
# C:\Users\ASMA\AppData\Local\Temp\ipykernel_12876\4009960244.py:16: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:mediumseagreen'` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# #Question 5: How many sets are typically played in a tennis match?

# %%
# only keep matches that actually finished with full set-by-set data:
# - has a winner
# - not flagged as retirement/incomplete
# - not a "final result only" record (no set details)
completed = master[
    (master['winner_code'].notna()) &
    (master['likely_retirement_or_incomplete'] == False) &
    (master['final_result_only'] == False)
]

# count how many sets have a score recorded
score_cols = ['home_team_score_period_1', 'home_team_score_period_2',
              'home_team_score_period_3', 'home_team_score_period_4',
              'home_team_score_period_5']

num_sets = completed[score_cols].notna().sum(axis=1)

print(num_sets.value_counts().sort_index())
print('Most common number of sets:', num_sets.mode()[0])
print('Average number of sets:', num_sets.mean())
# Out:
# 0      80
# 1      83
# 2    9426
# 3    3651
# Name: count, dtype: int64
# Most common number of sets: 2
# Average number of sets: 2.257401812688822

# %%
weird = completed[num_sets <= 1]
print(weird[['match_id', 'winner_code', 'final_result_only',
             'home_team_score_period_1', 'away_team_score_period_1',
             'home_team_score_period_2', 'away_team_score_period_2']].head(10))
# Out:
#      match_id  winner_code  final_result_only  home_team_score_period_1  \
# 0    11974053          1.0              False                       NaN
# 1    11974066          2.0              False                       NaN
# 44   12001976          2.0              False                       NaN
# 63   12002078          1.0              False                       NaN
# 64   12002109          2.0              False                       NaN
# 65   12002112          2.0              False                       NaN
# 221  12022528          2.0              False                       NaN
# 243  12023465          1.0              False                       6.0
# 285  11974052          2.0              False                       NaN
# 286  11974067          2.0              False                       NaN
#
#      away_team_score_period_1  home_team_score_period_2  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 44                        NaN                       NaN
# 63                        NaN                       NaN
# 64                        NaN                       NaN
# 65                        NaN                       NaN
# 221                       NaN                       NaN
# 243                       4.0                       NaN
# 285                       NaN                       NaN
# 286                       NaN                       NaN
#
#      away_team_score_period_2
# 0                         NaN
# 1                         NaN
# 44                        NaN
# 63                        NaN
# 64                        NaN
# 65                        NaN
# 221                       NaN
# 243                       NaN
# 285                       NaN
# 286                       NaN

# %%
# اگه فرضیه‌ی Walkover تأیید شد، این‌ها رو هم فیلتر کن
final_completed = completed[num_sets >= 2]
final_num_sets = final_completed[score_cols].notna().sum(axis=1)

print(final_num_sets.value_counts().sort_index())
print('Most common:', final_num_sets.mode()[0])
print('Average:', round(final_num_sets.mean(), 2))
# Out:
# 2    9426
# 3    3651
# Name: count, dtype: int64
# Most common: 2
# Average: 2.28

# %% [markdown]
# # Question 6: Which country has produced the most successful tennis players?

# %%
# (defined here as: total match wins grouped by player's country)

home_win = master.loc[master['winner_code'] == 1, ['home_team_player_id', 'home_team_country']]
away_win = master.loc[master['winner_code'] == 2, ['away_team_player_id', 'away_team_country']]

home_win.columns = ['player_id', 'country']
away_win.columns = ['player_id', 'country']

winners = pd.concat([home_win, away_win])

wins_by_country = winners['country'].value_counts()
print(wins_by_country.head(10))
print('Country with most wins:', wins_by_country.index[0], '-', wins_by_country.iloc[0], 'wins')
# Out:
# country
# France            985
# Italy             928
# USA               903
# Russia            624
# Argentina         538
# Germany           525
# Japan             522
# Spain             479
# Australia         435
# United Kingdom    359
# Name: count, dtype: int64
# Country with most wins: France - 985 wins

# %%
# Get top 10 countries by total wins
top10_countries = wins_by_country.head(10).sort_values()

fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(
    x=top10_countries.values,
    y=top10_countries.index,
    hue=top10_countries.index,
    color="mediumseagreen",
    legend=False,
    ax=ax
)

ax.spines[["right", "left", "top"]].set_visible(False)

ax.set_title(
    "Top 10 countries by total match wins",
    loc="left",
    weight="bold",
    color="gray",
    fontsize=16
)

ax.set_xlabel(
    "Number of wins",
    weight="bold",
    color="gray",
    fontsize=14
)

ax.set_ylabel(
    "Country",
    weight="bold",
    color="gray",
    fontsize=14
)

ax.tick_params(axis="x", colors="gray", labelsize="large")
ax.tick_params(axis="y", colors="gray", labelsize="large")
ax.tick_params(axis="x", which="major", length=0)

ax.grid(axis="x", linestyle="dashed")

# Display the number of wins on each bar
for i, wins in enumerate(top10_countries.values):
    ax.text(
        wins + 1,
        i,
        f"{wins:,}",
        va="center",
        fontsize=12,
        color="gray"
    )

plt.tight_layout()

plt.savefig(
    "../figures/top10_countries_by_wins.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
# Out:
# C:\Users\ASMA\AppData\Local\Temp\ipykernel_12876\3286564175.py:6: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:mediumseagreen'` for the same effect.
#
#   sns.barplot(

# %%
# مجموع بازی (نه فقط برد) به ازای هر کشور
home_all = master[['home_team_country']].rename(columns={'home_team_country': 'country'})
away_all = master[['away_team_country']].rename(columns={'away_team_country': 'country'})
all_matches_by_country = pd.concat([home_all, away_all])['country'].value_counts()

win_rate = (wins_by_country / all_matches_by_country * 100).dropna().sort_values(ascending=False)

# آستانه‌ی بالاتر: حداقل 300 بازی، برای مقایسه‌ی معنادار آماری
reliable = win_rate[all_matches_by_country >= 300].sort_values(ascending=False)
print(reliable.head(10))
# Out:
# country
# Argentina         52.233010
# Czech Republic    51.578947
# Australia         51.056338
# USA               50.588235
# Poland            50.301205
# Slovakia          50.255102
# Russia            50.000000
# Romania           50.000000
# Belgium           49.386503
# China             49.298597
# Name: count, dtype: float64

# %% [markdown]
# # preprocessing for Q7 to Q12

# %%
def get_stat(stat_name, period='ALL'):
    stats = flat_tables['statistics']
    sub = stats[(stats['statistic_name'] == stat_name) & (stats['period'] == period)]
    sub = sub[['match_id', 'home_value', 'away_value', 'home_total', 'away_total']].copy()
    sub = sub.rename(columns={
        'home_value': f'home_{stat_name}', 'away_value': f'away_{stat_name}',
        'home_total': f'home_{stat_name}_total', 'away_total': f'away_{stat_name}_total',
    })
    return sub.drop_duplicates(subset='match_id', keep='first')

# تابع کمکی: فیلتر مسابقات واقعا تمام‌شده 

def completed_matches(df):
    return df[
        (df['winner_code'].notna()) &
        (df['likely_retirement_or_incomplete'] == False) &
        (df['final_result_only'] == True)
    ].copy()


# تابع کمکی: جنسیت مسابقه (تأیید شده که home/away همیشه هم‌جنس‌اند 

def match_gender(df):
    return df['home_team_gender'].fillna(df['away_team_gender'])

print('helpers ready')
# Out:
# helpers ready

# %% [markdown]
# # Q7:What is the average number of aces per match?

# %%
# Average number of aces per match
# Matches that end prematurely (retirements) are excluded

aces = get_stat('aces')

q7 = master.merge(
    aces,
    on='match_id',
    how='inner'
)

q7 = completed_matches(q7)

# Convert ace values to numeric
q7['home_aces'] = pd.to_numeric(q7['home_aces'],errors='coerce')

q7['away_aces'] = pd.to_numeric(q7['away_aces'],errors='coerce')

# Remove matches with no ace data for either player
q7 = q7.dropna(subset=['home_aces', 'away_aces'],how='all')

# Remove invalid negative ace values
q7 = q7[
    (q7['home_aces'].fillna(0) >= 0) &
    (q7['away_aces'].fillna(0) >= 0)
].copy()

# Calculate total aces per match
q7['total_aces'] = (
    q7['home_aces'].fillna(0) +
    q7['away_aces'].fillna(0)
)

# Final result
average_aces = q7['total_aces'].mean()

print('Matches analyzed:', len(q7))
print('Average aces per match:', round(average_aces, 2))
# Out:
# Matches analyzed: 541
# Average aces per match: 5.0

# %%
# Histogram of total aces per match
fig, ax = plt.subplots(figsize=(10, 6))

ax.hist(
    q7['total_aces'],
    bins=40,
    color='mediumseagreen',
    edgecolor='white',
    alpha=0.85
)

# Mean line
mean_val = q7['total_aces'].mean()
ax.axvline(
    mean_val,
    color='red',
    linestyle='--',
    linewidth=2,
    label=f'mean = {mean_val:.1f}'
)

# Hide spines
ax.spines[["right", "left", "top"]].set_visible(False)

# Title
ax.set_title(
    "Distribution of total aces per match",
    loc="left",
    weight="bold",
    color="gray",
    fontsize=16
)

# Labels
ax.set_xlabel(
    "Total aces (both players)",
    weight="bold",
    color="gray",
    fontsize=14
)

ax.set_ylabel(
    "Number of matches",
    weight="bold",
    color="gray",
    fontsize=14
)

# Tick styling
ax.tick_params(axis="x", colors="gray", labelsize="large")
ax.tick_params(axis="y", colors="gray", labelsize="large")
ax.tick_params(axis="x", which="major", length=0)

# Grid
ax.grid(axis="y", linestyle="dashed", alpha=0.5)

# Legend
ax.legend(
    fontsize=12,
    frameon=False,
    labelcolor="gray"
)

plt.tight_layout()

plt.savefig(
    "../figures/q7_aces_histogram.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Q8:Is there a difference in the number of double faults based on gender?

# %%
df_stat = get_stat('double_faults')
sg_stat = get_stat('service_games_played')

# Merge double faults and service games data
q8 = master.merge(df_stat, on='match_id', how='inner')
q8 = q8.merge(sg_stat, on='match_id', how='left')

# Keep completed matches only
q8 = completed_matches(q8)

print('=' * 60)
print('Q8 - DOUBLE FAULTS BY GENDER')
print('=' * 60)

print('Unique matches with double-fault data:', q8['match_id'].nunique())


# --------------------------------------------------
# Create player-match records
# --------------------------------------------------

home_side = q8[
    ['home_team_player_id',
     'home_team_gender',
     'home_double_faults',
     'home_service_games_played']
].copy()

home_side.columns = [
    'player_id',
    'gender',
    'double_faults',
    'service_games'
]


away_side = q8[
    ['away_team_player_id',
     'away_team_gender',
     'away_double_faults',
     'away_service_games_played']
].copy()

away_side.columns = [
    'player_id',
    'gender',
    'double_faults',
    'service_games'
]


# Combine home and away players
players_q8 = pd.concat(
    [home_side, away_side],
    ignore_index=True
)


# --------------------------------------------------
# Data cleaning
# --------------------------------------------------

players_q8['double_faults'] = pd.to_numeric(
    players_q8['double_faults'],
    errors='coerce'
)

players_q8['service_games'] = pd.to_numeric(
    players_q8['service_games'],
    errors='coerce'
)

# Remove missing values required for the analysis
players_q8 = players_q8.dropna(
    subset=['double_faults', 'gender']
)

# Keep valid genders only
players_q8 = players_q8[
    players_q8['gender'].isin(['M', 'F'])
]

# Double faults cannot be negative
players_q8 = players_q8[
    players_q8['double_faults'] >= 0
]


print('Player-match records:', len(players_q8))
print('Unique players:', players_q8['player_id'].nunique())

print('\nUnique players by gender:')
print(
    players_q8.groupby('gender')['player_id'].nunique()
)


# --------------------------------------------------
# 1. Raw double faults
# --------------------------------------------------

summary_q8 = players_q8.groupby('gender')['double_faults'].agg(
    mean='mean',
    median='median',
    std='std',
    n='count'
).round(2).reset_index()

summary_q8['gender'] = summary_q8['gender'].replace({
    'M': 'Men',
    'F': 'Women'
})

print('\nRaw double faults by gender:')
display(summary_q8)


# --------------------------------------------------
# 2. Double faults per service game
# --------------------------------------------------

norm_q8 = players_q8[
    players_q8['service_games'] > 0
].copy()

norm_q8['df_per_service_game'] = (
    norm_q8['double_faults'] /
    norm_q8['service_games']
)


summary_q8_norm = norm_q8.groupby(
    'gender'
)['df_per_service_game'].agg(
    mean='mean',
    median='median',
    std='std',
    n='count'
).round(3).reset_index()

summary_q8_norm['gender'] = summary_q8_norm['gender'].replace({
    'M': 'Men',
    'F': 'Women'
})

print('\nDouble faults per service game by gender:')
display(summary_q8_norm)


# --------------------------------------------------
# 3. Overall rate by gender
# --------------------------------------------------

overall_q8 = norm_q8.groupby('gender').agg(
    total_double_faults=('double_faults', 'sum'),
    total_service_games=('service_games', 'sum'),
    player_matches=('player_id', 'count')
).reset_index()

overall_q8['df_per_service_game'] = (
    overall_q8['total_double_faults'] /
    overall_q8['total_service_games']
).round(4)

overall_q8['gender'] = overall_q8['gender'].replace({
    'M': 'Men',
    'F': 'Women'
})

print('\nOverall double-fault rate by gender:')
display(overall_q8)
# Out:
# ============================================================
# Q8 - DOUBLE FAULTS BY GENDER
# ============================================================
# Unique matches with double-fault data: 541
# Player-match records: 774
# Unique players: 645
#
# Unique players by gender:
# gender
# F    294
# M    351
# Name: player_id, dtype: int64
#
# Raw double faults by gender:
#   gender  mean  median   std    n
# 0  Women  3.65     3.0  2.79  351
# 1    Men  2.61     2.0  2.08  423
# Double faults per service game by gender:
#   gender   mean  median    std    n
# 0  Women  0.392   0.333  0.296  342
# 1    Men  0.260   0.222  0.198  423
# Overall double-fault rate by gender:
#   gender  total_double_faults  total_service_games  player_matches  \
# 0  Women               1264.0               3289.0             342
# 1    Men               1103.0               4230.0             423
#
#    df_per_service_game
# 0               0.3843
# 1               0.2608

# %%
from scipy.stats import mannwhitneyu

men_df = players_q8.loc[
    players_q8['gender'] == 'M',
    'double_faults'
]

women_df = players_q8.loc[
    players_q8['gender'] == 'F',
    'double_faults'
]

u_stat, p_value = mannwhitneyu(
    men_df,
    women_df,
    alternative='two-sided'
)

print('Mann-Whitney U test')
print('U statistic:', u_stat)
print('p-value:', p_value)

if p_value < 0.05:
    print('Result: There is a statistically significant difference in double faults by gender.')
else:
    print('Result: There is no statistically significant difference in double faults by gender.')
# Out:
# Mann-Whitney U test
# U statistic: 57988.0
# p-value: 1.0944585305748929e-07
# Result: There is a statistically significant difference in double faults by gender.

# %%
fig, ax = plt.subplots(1, figsize=(10, 6))

men_raw = players_q8[players_q8['gender'] == 'M']['double_faults']
women_raw = players_q8[players_q8['gender'] == 'F']['double_faults']

norm_means = norm_q8.groupby('gender')['df_per_service_game'].mean()
values = [norm_means.get('M', 0), norm_means.get('F', 0)]

bars = ax.bar(
    ['Men', 'Women'],
    values,
    color=['steelblue', 'salmon'],
    alpha=0.85,
    edgecolor='white'
)

# Hide spines
ax.spines[["right", "left", "top"]].set_visible(False)

# Title
ax.set_title(
    "Double faults per service game (normalized)",
    loc="left",
    weight="bold",
    color="gray",
    fontsize=16
)

# Labels
ax.set_xlabel(
    "Gender",
    weight="bold",
    color="gray",
    fontsize=14
)

ax.set_ylabel(
    "Double faults per service game",
    weight="bold",
    color="gray",
    fontsize=14
)

# Tick styling
ax.tick_params(axis="x", colors="gray", labelsize="large")
ax.tick_params(axis="y", colors="gray", labelsize="large")
ax.tick_params(axis="x", which="major", length=0)

# Grid
ax.grid(axis="y", linestyle="dashed", alpha=0.5)

# Display the value on each bar
for bar, v in zip(bars, values):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        v + 0.002,
        f'{v:.3f}',
        ha='center',
        fontsize=12,
        color='gray'
    )

plt.tight_layout()

plt.savefig(
    "../figures/q8_double_faults_by_gender.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Q9:Which player has won the most tournaments in a single month?

# %%
#Tournament champion = Final winner; each tournament has only one final.
#Data covers only February–March 2024.


print('unique round names:', master['round_name'].dropna().unique())

q9 = master.dropna(subset=['round_name', 'winner_code', 'start_datetime']).copy()
finals = q9[q9['round_name'] == 'Final'].copy()
print('finals found:', len(finals))

dup_finals = finals['tournament_tournament_id'].duplicated().sum()
print('duplicate finals per tournament:', dup_finals)

finals = finals.drop_duplicates(subset='tournament_tournament_id', keep='first')

finals['champion'] = np.where(finals['winner_code'] == 1,
                               finals['home_team_full_name'], finals['away_team_full_name'])
finals = finals.dropna(subset=['champion'])

finals['match_date'] = pd.to_datetime(finals['start_datetime'], unit='s')
finals['month'] = finals['match_date'].dt.to_period('M')

champion_counts = (finals.groupby(['champion', 'month']).size()
                   .reset_index(name='tournaments_won').sort_values('tournaments_won', ascending=False))
display(champion_counts.head(10))
# Out:
# unique round names: ['Round of 16' 'Quarterfinal' 'Round of 32' 'Semifinal'
#  'Qualification round 1' 'Final' 'Round of 64' 'Qualification round 2'
#  'Semifinals' 'Quarterfinals' 'Round of 128']
# finals found: 227
# duplicate finals per tournament: 0
#                               champion    month  tournaments_won
# 54                       Gengel, Marek  2024-02                3
# 82               Jianu, Filip Cristian  2024-03                3
# 144                      Popko, Dmitry  2024-02                3
# 132                       Nicod, Jakub  2024-03                3
# 81                        Jasika, Omar  2024-02                2
# 186                  Valentova, Tereza  2024-02                2
# 32               Ciric Bagaric, Lucija  2024-02                2
# 30                    Chidekh, Clement  2024-02                2
# 40   Dellien Velasco, Murkel Alejandro  2024-02                2
# 87                  Kessler, McCartney  2024-02                2

# %%
# Find all players tied for the highest number of tournament wins in one month
max_tournaments = champion_counts['tournaments_won'].max()

top_players = champion_counts[
    champion_counts['tournaments_won'] == max_tournaments
]

print(
    f"Maximum tournaments won by a player in a single month: "
    f"{max_tournaments}"
)

display(top_players)
# Out:
# Maximum tournaments won by a player in a single month: 3
#                   champion    month  tournaments_won
# 54           Gengel, Marek  2024-02                3
# 82   Jianu, Filip Cristian  2024-03                3
# 144          Popko, Dmitry  2024-02                3
# 132           Nicod, Jakub  2024-03                3

# %%
fig, ax = plt.subplots(figsize=(10, 6))

top10 = champion_counts.head(10).iloc[::-1]

bars = ax.barh(
    top10['champion'],
    top10['tournaments_won'],
    color='mediumseagreen',
    alpha=0.85,
    edgecolor='white'
)

# Hide spines
ax.spines[["right", "left", "top"]].set_visible(False)

# Title
ax.set_title(
    "Top 10 players by total tournaments_won (Feb–Mar 2024)",
    loc="left",
    weight="bold",
    color="gray",
    fontsize=16
)

# Labels
ax.set_xlabel(
    "Number of tournaments_won",
    weight="bold",
    color="gray",
    fontsize=14
)

ax.set_ylabel(
    "Player",
    weight="bold",
    color="gray",
    fontsize=14
)

# Tick styling
ax.tick_params(axis="x", colors="gray", labelsize="large")
ax.tick_params(axis="y", colors="gray", labelsize="large")
ax.tick_params(axis="y", which="major", length=0)

# Grid
ax.grid(axis="x", linestyle="dashed", alpha=0.5)


plt.tight_layout()

plt.show()

# %% [markdown]
# # Q10:. Is there a correlation between a player's height and their ranking?

# %%
# Q10: Is there a correlation between a player's height and their ranking?

# The ranking is inverted: a lower number = better.
# The men's (ATP) and women's (WTA) rankings are two separate systems;
# therefore, they are analyzed separately.
# Each player should be counted only once.

home_p = master[
    ['home_team_player_id',
     'home_team_gender',
     'home_team_height',
     'home_team_current_rank']
].copy()

home_p.columns = ['player_id', 'gender', 'height', 'rank']


away_p = master[
    ['away_team_player_id',
     'away_team_gender',
     'away_team_height',
     'away_team_current_rank']
].copy()

away_p.columns = ['player_id', 'gender', 'height', 'rank']


# Combine home and away players
all_players = pd.concat([home_p, away_p], ignore_index=True)


# Convert numeric columns
all_players['height'] = pd.to_numeric(
    all_players['height'],
    errors='coerce'
)

all_players['rank'] = pd.to_numeric(
    all_players['rank'],
    errors='coerce'
)


# Remove invalid/missing values
all_players = all_players.dropna(
    subset=['player_id', 'height', 'rank']
)

all_players = all_players[
    all_players['height'].between(1.5, 2.2)
]

all_players = all_players[
    all_players['rank'] > 0
]


# Keep each player only once
unique_players = all_players.drop_duplicates(
    subset='player_id',
    keep='first'
)

print('Unique players:', len(unique_players))

print('\nUnique players by gender:')
print(unique_players.groupby('gender')['player_id'].nunique())


# Separate men and women
men = unique_players[
    unique_players['gender'] == 'M'
]

women = unique_players[
    unique_players['gender'] == 'F'
]


# --------------------------------------------------
# Spearman correlation
# --------------------------------------------------

from scipy.stats import spearmanr

rho_men, p_men = spearmanr(
    men['height'],
    men['rank']
)

rho_women, p_women = spearmanr(
    women['height'],
    women['rank']
)


# --------------------------------------------------
# Summary table
# --------------------------------------------------

result_q10 = pd.DataFrame({
    'group': ['Men (ATP)', 'Women (WTA)'],
    'correlation': [
        round(rho_men, 3),
        round(rho_women, 3)
    ],
    'p_value': [
        round(p_men, 4),
        round(p_women, 4)
    ],
    'mean_height': [
        round(men['height'].mean(), 3),
        round(women['height'].mean(), 3)
    ],
    'players': [
        len(men),
        len(women)
    ]
})


result_q10['significant'] = result_q10['p_value'].apply(
    lambda p: 'Yes' if p < 0.05 else 'No'
)

display(result_q10)


# --------------------------------------------------
# Interpretation
# --------------------------------------------------

def interpret_correlation(rho, p_value):

    # Strength of correlation
    a = abs(rho)

    if a < 0.1:
        strength = 'negligible'
    elif a < 0.3:
        strength = 'weak'
    elif a < 0.5:
        strength = 'moderate'
    else:
        strength = 'strong'

    # Direction
    # Lower ranking number = better ranking
    if rho < 0:
        direction = 'taller players tend to have better rankings'
    else:
        direction = 'taller players tend to have worse rankings'

    # Statistical significance
    if p_value < 0.05:
        significance = 'statistically significant'
    else:
        significance = 'not statistically significant'

    return f'{strength} negative/positive correlation ({direction}), {significance}'


print('\nInterpretation:')

print(
    f"Men (ATP): rho = {rho_men:.3f}, "
    f"p-value = {p_men:.4f}"
)

print(
    f"Women (WTA): rho = {rho_women:.3f}, "
    f"p-value = {p_women:.4f}"
)


# Simple final conclusion
if p_men < 0.05:
    print(
        f'\nMen: There is a statistically significant '
        f'correlation between height and ranking.'
    )
else:
    print(
        f'\nMen: There is no statistically significant '
        f'correlation between height and ranking.'
    )


if p_women < 0.05:
    print(
        f'Women: There is a statistically significant '
        f'correlation between height and ranking.'
    )
else:
    print(
        f'Women: There is no statistically significant '
        f'correlation between height and ranking.'
    )
# Out:
# Unique players: 1334
#
# Unique players by gender:
# gender
# F     252
# M    1081
# Name: player_id, dtype: int64
#          group  correlation  p_value  mean_height  players significant
# 0    Men (ATP)       -0.123   0.0001        1.843     1081         Yes
# 1  Women (WTA)       -0.225   0.0003        1.732      252         Yes
# Interpretation:
# Men (ATP): rho = -0.123, p-value = 0.0001
# Women (WTA): rho = -0.225, p-value = 0.0003
#
# Men: There is a statistically significant correlation between height and ranking.
# Women: There is a statistically significant correlation between height and ranking.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6), sharey=True)

def scatter_with_trend(ax, data, color, title):
    ax.scatter(data['height'], data['rank'], alpha=0.35, color=color, s=25)
    z = np.polyfit(data['height'], data['rank'], 1)
    p = np.poly1d(z)
    x_line = np.linspace(data['height'].min(), data['height'].max(), 100)
    ax.plot(x_line, p(x_line), color='red', linestyle='--', linewidth=2)
    r = data['height'].corr(data['rank'])

    # Hide spines
    ax.spines[["right", "left", "top"]].set_visible(False)

    # Title
    ax.set_title(
        f"{title}  (r = {r:.3f})",
        loc="left",
        weight="bold",
        color="gray",
        fontsize=16
    )

    # Labels
    ax.set_xlabel(
        "Height (m)",
        weight="bold",
        color="gray",
        fontsize=14
    )

    # Tick styling
    ax.tick_params(axis="x", colors="gray", labelsize="large")
    ax.tick_params(axis="y", colors="gray", labelsize="large")
    ax.tick_params(axis="x", which="major", length=0)

    # Grid
    ax.grid(linestyle="dashed", alpha=0.5)

scatter_with_trend(ax1, men, 'steelblue', 'Men (ATP)')
scatter_with_trend(ax2, women, 'salmon', 'Women (WTA)')

# Y label with styling
ax1.set_ylabel(
    "Ranking (lower = better)",
    weight="bold",
    color="gray",
    fontsize=14
)
ax1.invert_yaxis()

plt.tight_layout()

plt.show()

# %% [markdown]
# # Q11:What is the average duration of matches?

# %%
#Note on this dataset: All matches are best-of-three sets, so there is no need to distinguish between formats.

#Reasonable duration for a tennis match: 20 minutes to 6 hours

q11 = completed_matches(master)
q11['gender'] = match_gender(q11)
q11 = q11[q11['total_duration_sec'] > 0]

before_range = len(q11)
q11 = q11[q11['total_duration_sec'].between(1200, 21600)]
print('removed as out-of-range:', before_range - len(q11))

q11['duration_minutes'] = q11['total_duration_sec'] / 60
print('matches remaining:', len(q11))

print('=' * 60)
print('Descriptive statistics table of MATCH DURATION')
print('=' * 60)
result_q11 = pd.DataFrame({
    'metric': ['mean_minutes', 'median_minutes', 'std_minutes', 'min_minutes', 'max_minutes', 'matches'],
    'value': [round(q11['duration_minutes'].mean(), 1), round(q11['duration_minutes'].median(), 1),
              round(q11['duration_minutes'].std(), 1), round(q11['duration_minutes'].min(), 1),
              round(q11['duration_minutes'].max(), 1), len(q11)]
})
display(result_q11)

print(f"The average match duration is: {round(q11['duration_minutes'].mean(), 1)} minutes")
# Out:
# removed as out-of-range: 1
# matches remaining: 521
# ============================================================
# Descriptive statistics table of MATCH DURATION
# ============================================================
#            metric  value
# 0    mean_minutes   96.1
# 1  median_minutes   91.1
# 2     std_minutes   30.1
# 3     min_minutes   20.3
# 4     max_minutes  207.4
# 5         matches  521.0
# The average match duration is: 96.1 minutes

# %%
# Additional Analysis
print('\n' + '=' * 60)
print('MATCH DURATION BY GENDER')
print('=' * 60)
by_gender_q11 = q11.groupby('gender')['duration_minutes'].agg(
    mean='mean', median='median', matches='count').round(1).reset_index()
display(by_gender_q11)


print('\n' + '=' * 60)
print('MATCH DURATION BY NUMBER OF SETS')
print('=' * 60)
score_cols = ['home_team_score_period_1', 'home_team_score_period_2', 'home_team_score_period_3']
q11['sets_played'] = q11[score_cols].notna().sum(axis=1)
by_sets_q11 = q11[q11['sets_played'] > 0].groupby('sets_played')['duration_minutes'].agg(
    mean='mean', matches='count').round(1).reset_index()
display(by_sets_q11)
# Out:
# ============================================================
# MATCH DURATION BY GENDER
# ============================================================
#   gender       mean     median  matches
# 0      F  97.112972  92.716667      203
# 1      M  97.050463      90.45      252
# ============================================================
# MATCH DURATION BY NUMBER OF SETS
# ============================================================
#    sets_played        mean  matches
# 0            2   84.821852      360
# 1            3  121.243478      161

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.hist(
    q11['duration_minutes'],
    bins=40,
    color='mediumseagreen',
    edgecolor='white',
    alpha=0.85
)

# Mean line
mean_min = q11['duration_minutes'].mean()
ax.axvline(
    mean_min,
    color='red',
    linestyle='--',
    linewidth=2,
    label=f'mean = {mean_min:.0f} min'
)

# Hide spines
ax.spines[["right", "left", "top"]].set_visible(False)

# Title
ax.set_title(
    "Distribution of match duration",
    loc="left",
    weight="bold",
    color="gray",
    fontsize=16
)

# Labels
ax.set_xlabel(
    "Duration (minutes)",
    weight="bold",
    color="gray",
    fontsize=14
)

ax.set_ylabel(
    "Number of matches",
    weight="bold",
    color="gray",
    fontsize=14
)

# Tick styling
ax.tick_params(axis="x", colors="gray", labelsize="large")
ax.tick_params(axis="y", colors="gray", labelsize="large")
ax.tick_params(axis="x", which="major", length=0)

# Grid
ax.grid(axis="y", linestyle="dashed", alpha=0.5)

# Legend
ax.legend(
    fontsize=12,
    frameon=False,
    labelcolor="gray"
)

plt.tight_layout()


plt.show()

# %% [markdown]
# # Q12:What is the average number of games per set in men's matches compared to women's matches?

# %%
#Valid Set: Winning result of a maximum of 7 games, and a total game count between 6 and 13.
#Since all matches are best-of-three sets, comparing set-level performance does not require distinguishing between formats.
#Incomplete sets (retirements) are removed.


q12 = completed_matches(master)
q12['gender'] = match_gender(q12)

sets_list = []
for i in range(1, 4):   # Only up to 3, because this dataset has a maximum of 3 sets.
    home_col = f'home_team_score_period_{i}'
    away_col = f'away_team_score_period_{i}'
    
    # Keep only sets that were actually played
    valid = q12[q12[home_col].notna() & q12[away_col].notna()].copy()
    temp = pd.DataFrame({
        'match_id': valid['match_id'].values,
        'home_games': pd.to_numeric(valid[home_col], errors='coerce').values,
        'away_games': pd.to_numeric(valid[away_col], errors='coerce').values,
        'gender': valid['gender'].values,
    })
    sets_list.append(temp)
    
# Combine all played sets
all_sets = pd.concat(sets_list, ignore_index=True)

# Calculate total games in each set
all_sets['total_games'] = all_sets['home_games'] + all_sets['away_games']

# Remove records with missing values
all_sets = all_sets.dropna(subset=['total_games', 'gender'])

all_sets = all_sets[all_sets['gender'].isin(['M', 'F'])]

# Average number of games per set by gender
summary_q12 = all_sets.groupby('gender')['total_games'].agg(
    mean='mean', median='median', std='std', min='min', max='max', sets='count').round(2).reset_index()

summary_q12['gender'] = summary_q12['gender'].replace({'M': 'Men', 'F': 'Women'})
display(summary_q12)

# Calculate the average for each gender
m12 = all_sets[all_sets['gender'] == 'M']['total_games'].mean()
f12 = all_sets[all_sets['gender'] == 'F']['total_games'].mean()# Percentage difference between the two averages
difference_q12 = (
    abs(m12 - f12) /
    ((m12 + f12) / 2)
) * 100


print('=' * 60)
print('Q12 - AVERAGE GAMES PER SET')
print('=' * 60)

print(f'Men: {m12:.2f} games per set')
print(f'Women: {f12:.2f} games per set')
print(f'Percentage difference: {difference_q12:.1f}%')
print(f'Total valid sets analyzed: {len(all_sets)}')
# Out:
#   gender   mean  median   std  min   max  sets
# 0  Women  10.26    10.0  2.93  2.0  28.0   680
# 1    Men  10.55    10.0  3.02  3.0  28.0  1040
# ============================================================
# Q12 - AVERAGE GAMES PER SET
# ============================================================
# Men: 10.55 games per set
# Women: 10.26 games per set
# Percentage difference: 2.8%
# Total valid sets analyzed: 1720

# %%
fig, ax = plt.subplots(figsize=(10, 6))

means = all_sets.groupby('gender')['total_games'].mean()
values = [means.get('M', 0), means.get('F', 0)]

bars = ax.bar(
    ['Men', 'Women'],
    values,
    color=['steelblue', 'salmon'],
    alpha=0.85,
    edgecolor='white',
    width=0.55
)

# Hide spines
ax.spines[["right", "left", "top"]].set_visible(False)

# Title
ax.set_title(
    "Average games per set: Men vs Women",
    loc="left",
    weight="bold",
    color="gray",
    fontsize=16
)

# Labels
ax.set_xlabel(
    "Gender",
    weight="bold",
    color="gray",
    fontsize=14
)

ax.set_ylabel(
    "Games per set",
    weight="bold",
    color="gray",
    fontsize=14
)

# Tick styling
ax.tick_params(axis="x", colors="gray", labelsize="large")
ax.tick_params(axis="y", colors="gray", labelsize="large")
ax.tick_params(axis="x", which="major", length=0)

# Grid
ax.grid(axis="y", linestyle="dashed", alpha=0.5)

# Y limits
ax.set_ylim(min(values) - 1, max(values) + 0.5)

# Display the value on each bar
for bar, v in zip(bars, values):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        v + 0.05,
        f'{v:.2f}',
        ha='center',
        fontsize=13,
        fontweight='bold',
        color='gray'
    )

plt.tight_layout()

plt.show()

# %% [markdown]
# # Q13: What is the distribution of left-handed versus right-handed players?

# %%
# Stack home and away player info into one column set
home = master[['home_team_player_id', 'home_team_plays']]
away = master[['away_team_player_id', 'away_team_plays']]

home.columns = ['player_id', 'plays']
away.columns = ['player_id', 'plays']

players = pd.concat([home, away])

players = players.drop_duplicates(subset='player_id')

players = players.dropna(subset=['plays'])

hand_distribution = players['plays'].value_counts()

hand_result = pd.DataFrame({
    'Count': hand_distribution,
    'Percentage': (hand_distribution / hand_distribution.sum() * 100).round(2).astype(str) + '%'
})
hand_result
# Out:
#               Count Percentage
# plays
# right-handed   1013     88.39%
# left-handed     133     11.61%

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(
    x=hand_result.index,
    y=hand_result['Count'],
    hue=hand_result.index,
    color="mediumseagreen",
    legend=False,
    ax=ax
)

ax.spines[["right", "left", "top"]].set_visible(False)

ax.set_title(
    "The majority of players are right-handed",
    loc="left",
    weight="bold",
    color="gray",
    fontsize=16
)

ax.set_xlabel(
    "Playing hand",
    weight="bold",
    color="gray",
    fontsize=14
)

ax.set_ylabel(
    "Number of players",
    weight="bold",
    color="gray",
    fontsize=14
)

ax.tick_params(axis="x", colors="gray", labelsize="large")
ax.tick_params(axis="y", colors="gray", labelsize="large")
ax.tick_params(axis="y", which="major", length=0)

ax.grid(axis="y", linestyle="dashed")

# نمایش  درصد روی هر میله
for i, percentage in enumerate(hand_result['Percentage']):
    ax.text(
        i,
        hand_result['Count'].iloc[i] + 20,
        percentage,
        ha="center",
        fontsize=12,
        color="gray"
    )

plt.tight_layout()

plt.savefig(
    "../figures/handedness_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
# Out:
# C:\Users\ASMA\AppData\Local\Temp\ipykernel_12876\878275742.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:mediumseagreen'` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # Q14:  What is the most common type of surface used in tournaments?

# %%
df_tournament = master[['match_id','tournament_tournament_id', 'tournament_ground_type']]

# Quality check: missing surface values
missing_surface = df_tournament['tournament_ground_type'].isna().sum()

print(f"Missing ground_type values: {missing_surface}")

# 1. Check the number of surface types for each tournament
surface_count = (
    df_tournament
    .groupby('tournament_tournament_id')['tournament_ground_type']
    .nunique()
)

# 2. Keep only tournaments with one consistent surface type
valid_ids = surface_count[surface_count == 1].index

valid_tournaments = df_tournament[
    df_tournament['tournament_tournament_id'].isin(valid_ids)
]

# 3. Count distinct tournaments for each surface type
surface = (
    valid_tournaments
    .groupby('tournament_ground_type')['tournament_tournament_id']
    .nunique()
    .sort_values(ascending=False)
)

print(surface)

# 4. Most common surface
most_common_surface = surface.index[0]
most_common_count = surface.iloc[0]

print(
    f"\nThe most common surface type is '{most_common_surface}', "
    f"used in {most_common_count} tournaments."
)
# Out:
# Missing ground_type values: 273
# tournament_ground_type
# Hardcourt outdoor    236
# Red clay             180
# Hardcourt indoor      83
# Grass                  6
# Red clay indoor        6
# Carpet indoor          5
# Synthetic outdoor      3
# Green clay             1
# Name: tournament_tournament_id, dtype: int64
#
# The most common surface type is 'Hardcourt outdoor', used in 236 tournaments.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(16, 7))

sns.barplot(
    x=surface.values,
    y=surface.index,
    hue=surface.index,
    color="mediumseagreen",
    legend=False,
    ax=ax
)

# حذف حاشیه‌های اضافی
ax.spines[["right", "left", "top"]].set_visible(False)

# عنوان
ax.set_title(
    "Hardcourt outdoor is the most common tournament surface",
    loc="left",
    weight="bold",
    color="gray",
    fontsize=16
)

# نام محورها
ax.set_xlabel(
    "Number of tournaments",
    weight="bold",
    color="gray",
    loc="left",
    fontsize=14
)

ax.set_ylabel(
    "Surface type",
    weight="bold",
    color="gray",
    fontsize=14
)

# تنظیم رنگ و اندازه اعداد محورها
ax.tick_params(axis="x", colors="gray", labelsize="large")
ax.tick_params(axis="y", colors="gray", labelsize="large")

# حذف خط‌های کوچک کنار محور Y
ax.tick_params(axis="y", which="major", length=0)

# خطوط راهنمای عمودی
ax.grid(axis="x", linestyle="dashed")


# نمایش مقدار روی هر میله
for i, value in enumerate(surface.values):
    ax.text(
        value + 2,
        i,
        str(value),
        va="center",
        fontsize=12,
        color="gray"
    )

plt.tight_layout()

plt.savefig(
    "../figures/tournament_surface.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
# Out:
# C:\Users\ASMA\AppData\Local\Temp\ipykernel_12876\2286166841.py:6: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:mediumseagreen'` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # Q15:How many distinct countries are represented in the dataset?

# %%
# Stack home and away player info into one column set
home = master[['home_team_player_id', 'home_team_country']]
away = master[['away_team_player_id', 'away_team_country']]

home.columns = ['player_id', 'country']
away.columns = ['player_id', 'country']

players = pd.concat([home, away])

players = players.drop_duplicates(subset='player_id')

countries = players['country'].dropna().nunique()
print (f'The number of distinct countries that participated in the competitions is {countries}.')
# Out:
# The number of distinct countries that participated in the competitions is 100.

# %%
# Stack home and away player information
home = master[['home_team_player_id', 'home_team_country']]
away = master[['away_team_player_id', 'away_team_country']]

home.columns = ['player_id', 'country']
away.columns = ['player_id', 'country']

players = pd.concat([home, away], ignore_index=True)

# Quality check and cleaning
print("Missing country values:", players['country'].isna().sum())

players['country'] = players['country'].str.strip()

print("Empty country values:", (players['country'] == '').sum())

# Number of distinct countries
countries = players['country'].dropna().nunique()

print(
    f"The number of distinct countries that participated in the competitions is {countries}."
)
# Out:
# Missing country values: 9557
# Empty country values: 0
# The number of distinct countries that participated in the competitions is 101.

# %% [markdown]
# # Q16: Which player has the highest winning percentage against top-10 ranked opponents?

# %%
home = master[['home_team_player_id', 'home_team_full_name', 'away_team_current_rank']].copy()
home.columns = ['player_id', 'name', 'opponent_rank']
home['won'] = master['winner_code'] == 1

away = master[['away_team_player_id', 'away_team_full_name', 'home_team_current_rank']].copy()
away.columns = ['player_id', 'name', 'opponent_rank']
away['won'] = master['winner_code'] == 2

vs_all = pd.concat([home, away])

vs_top10 = vs_all[vs_all['opponent_rank'] <= 10]

summary = vs_top10.groupby('player_id').agg(
    name=('name', 'first'),
    matches=('won', 'size'),
    wins=('won', 'sum')
)
summary['win_pct'] = summary['wins'] / summary['matches'] * 100

result = summary.sort_values(
    by=['win_pct', 'wins', 'matches'],
    ascending=[False, False, False]
)
print(result.head(20))
# Out:
#                            name  matches  wins     win_pct
# player_id
# 185388.0           Humbert, Ugo        3     3  100.000000
# 228272.0           Swiatek, Iga        3     3  100.000000
# 19578.0       Kerber, Angelique        1     1  100.000000
# 36067.0         Tsurenko, Lesia        1     1  100.000000
# 47603.0        Monteiro, Thiago        1     1  100.000000
# 50641.0            Vekić, Donna        1     1  100.000000
# 59702.0    Haddad Maia, Beatriz        1     1  100.000000
# 64580.0            Ćorić, Borna        1     1  100.000000
# 69208.0        Paolini, Jasmine        1     1  100.000000
# 87690.0        Thompson, Jordan        1     1  100.000000
# 90664.0      Kalinina, Anhelina        1     1  100.000000
# 127208.0       Altmaier, Daniel        1     1  100.000000
# 163480.0      Bublik, Alexander        1     1  100.000000
# 256104.0        Volynets, Katie        1     1  100.000000
# 262594.0       Avanesyan, Elina        1     1  100.000000
# 289233.0            Nardi, Luca        1     1  100.000000
# 372312.0          Mensik, Jakub        1     1  100.000000
# 406728.0        Michelsen, Alex        1     1  100.000000
# 275923.0        Alcaraz, Carlos        4     3   75.000000
# 19728.0         Cirstea, Sorana        3     2   66.666667

# %% [markdown]
# # Q17:What is the average number of breaks of serve per match?

# %%
df_power['break_occurred'].value_counts(dropna=False)
# Out:
# break_occurred
# False    153483
# True      77098
# Name: count, dtype: int64

# %%
# Calculate the number of breaks of serve for each match

breaks_per_match = (
    df_power
    .groupby('match_id')
    ['break_occurred']
    .sum()
    .reset_index(name='breaks_of_serve')
)

# Top 3 matches with the highest number of service breaks
top3_breaks = breaks_per_match.sort_values(by='breaks_of_serve', ascending=False).head(3)
print(top3_breaks)

# Average number of breaks of serve per match

average_breaks = breaks_per_match['breaks_of_serve'].mean()

print(
    f"Average number of breaks of serve per match: "
    f"{average_breaks:.2f}"
)
# Out:
#       match_id  breaks_of_serve
# 9481  12175864               29
# 5786  12124270               25
# 9507  12176348               22
# Average number of breaks of serve per match: 6.93

# %%
# Custom 18: Does winning the first set predict winning the match?

master['home_won_set1'] = master['home_team_score_period_1'] > master['away_team_score_period_1']
master['home_won_match'] = master['winner_code'] == 1

# only matches with a known first-set score and a known winner
valid = master.dropna(subset=['home_team_score_period_1', 'away_team_score_period_1', 'winner_code'])

match_rate = (valid['home_won_set1'] == valid['home_won_match']).mean()
print('Set 1 winner also wins the match:', round(match_rate * 100, 1), '%')
# Out:
# Set 1 winner also wins the match: 84.8 %

# %%
# Custom 19: Do seeded players actually perform better?

# only matches with a known winner
completed = master[master['winner_code'].notna()]

home = completed[['home_team_seed']].copy()
home['seeded'] = home['home_team_seed'].notna()
home['won'] = completed['winner_code'] == 1

away = completed[['away_team_seed']].copy()
away['seeded'] = away['away_team_seed'].notna()
away['won'] = completed['winner_code'] == 2

seed_data = pd.concat([home[['seeded', 'won']], away[['seeded', 'won']]])

print(seed_data.groupby('seeded')['won'].mean())
# Out:
# seeded
# False    0.480227
# True     0.553521
# Name: won, dtype: float64

# %%
# custom 20 :How many matches contain violations of the standard tennis scoring rules?

# Number of invalid and total matches
invalid_matches = invalid_pbp['match_id'].nunique()
total_matches = final_pbp['match_id'].nunique()

# Percentage of invalid matches
invalid_match_percentage = 100 * invalid_matches / total_matches

print(f"Number of matches containing violations of standard tennis scoring rules:{invalid_matches:,}")

print(f"Total number of matches analyzed:{total_matches:,}")

print(f"Percentage of matches containing scoring violations:{invalid_match_percentage:.2f}%")

# %%
# custom 21: Does the player with more aces have a higher probability of winning the match?
df_stats = flat_tables['statistics']
# Select rows containing Ace statistics
aces = df_stats[
    df_stats['statistic_name'].eq('aces')
].copy()

# Convert Ace values to numeric
aces['home_aces'] = pd.to_numeric(aces['home_value'], errors='coerce')
aces['away_aces'] = pd.to_numeric(aces['away_value'], errors='coerce')

# Keep one row per match
aces = aces[['match_id', 'home_aces', 'away_aces']].drop_duplicates('match_id')

# Add the match winner
ace_analysis = aces.merge( master[['match_id', 'winner_code']],on='match_id', how='inner')

# Identify whether the player with more aces won
ace_analysis['ace_leader_won'] = np.where(
    ace_analysis['home_aces'] > ace_analysis['away_aces'],
    ace_analysis['winner_code'].eq(1),
    np.where(
        ace_analysis['away_aces'] > ace_analysis['home_aces'],
        ace_analysis['winner_code'].eq(2),
        np.nan))

ace_analysis = ace_analysis.dropna(subset=['ace_leader_won'])

ace_win_rate = ace_analysis['ace_leader_won'].mean() * 100

print(f"Win rate when a player has more aces: {ace_win_rate:.2f}%")
# Out:
# Win rate when a player has more aces: 59.43%

# %%
from scipy.stats import binomtest

# Keep only valid comparisons
valid = ace_analysis['ace_leader_won'].dropna().astype(bool)

# Number of successful cases
wins = int(valid.sum())

# Total number of valid matches
matches = int(len(valid))

# Calculate win rate
ace_win_rate = wins / matches * 100

# Test whether the win probability is significantly greater than 50%
test = binomtest(
    k=wins,
    n=matches,
    p=0.5,
    alternative='greater'
)

print(f"Matches analyzed: {matches}")
print(f"More-aces player wins: {wins}")
print(f"Win rate: {ace_win_rate:.2f}%")
print(f"P-value: {test.pvalue:.2e}")

alpha = 0.05

if test.pvalue < alpha:
    print(
        "Conclusion: Yes, there is a statistically significant "
        "relationship between having more aces and winning the match."
    )
else:
    print(
        "Conclusion: No statistically significant relationship was "
        "found between having more aces and winning the match."
    )
# Out:
# Matches analyzed: 7981
# More-aces player wins: 4743
# Win rate: 59.43%
# P-value: 2.88e-64
# Conclusion: Yes, there is a statistically significant relationship between having more aces and winning the match.

# %%
# custom 22: what percentage  of matches were won by the player who took the first set?
qs3 = master[['match_id', 'winner_code',
              'home_team_score_period_1', 'away_team_score_period_1',
              'likely_retirement_or_incomplete', 'final_result_only']].copy()

qs3 = completed_matches(qs3)

print('number of matches before cleanup :', len(qs3))

qs3['home_team_score_period_1'] = pd.to_numeric(qs3['home_team_score_period_1'], errors='coerce')
qs3['away_team_score_period_1'] = pd.to_numeric(qs3['away_team_score_period_1'], errors='coerce')

#rows that do not have a first set are meaningless for this question
qs3 = qs3.dropna(subset=['home_team_score_period_1', 'away_team_score_period_1'])

#eliminate the impossible scenario: a tennis set never end with the game tied
qs3 = qs3[qs3['home_team_score_period_1'] != qs3['away_team_score_period_1']]

print('number of matches after cleanup:', len(qs3))

#who won the first game
qs3['home_won_set1'] = qs3['home_team_score_period_1'] > qs3['away_team_score_period_1']

#was the winner of the entire match the same as winner of the first set?
qs3['set1_winner_won_match'] = (
    (qs3['home_won_set1'] & (qs3['winner_code'] == 1)) |
    (~qs3['home_won_set1'] & (qs3['winner_code'] == 2))
)


set1_predicts_match_pct = qs3['set1_winner_won_match'].mean() * 100

result_qs3 = pd.DataFrame({
    'metric': ['set1_winner_wins_match_%','set1_loser_wins_match_%','matches_analyzed'],
    'value': [round(set1_predicts_match_pct, 1),round(100 - set1_predicts_match_pct, 1),len(qs3)]
})

display(result_qs3)


total_matches = master['match_id'].nunique()
used_matches = qs3['match_id'].nunique()

print(f"from total {total_matches} matches, {used_matches} were used ({used_matches / total_matches * 100:.1f}%)")
# Out:
# number of matches before cleanup : 1062
# number of matches after cleanup: 1042
#                      metric   value
# 0  set1_winner_wins_match_%    86.4
# 1   set1_loser_wins_match_%    13.6
# 2          matches_analyzed  1042.0
# from total 16739 matches, 1042 were used (6.2%)

# %%
# custom 23: Is there a relationship between a player's ranking and their probability of winning a match?

# Select the required columns
qs_rank = master[
    [
        'match_id',
        'winner_code',
        'home_team_current_rank',
        'away_team_current_rank',
        'likely_retirement_or_incomplete',
        'final_result_only'
    ]
].copy()

# Keep completed matches only
qs_rank = completed_matches(qs_rank)

print('Matches before cleanup:', qs_rank['match_id'].nunique())

# Convert rankings to numeric
qs_rank['home_team_current_rank'] = pd.to_numeric(
    qs_rank['home_team_current_rank'],
    errors='coerce'
)

qs_rank['away_team_current_rank'] = pd.to_numeric(
    qs_rank['away_team_current_rank'],
    errors='coerce'
)

# Remove matches without ranking information
qs_rank = qs_rank.dropna(
    subset=[
        'home_team_current_rank',
        'away_team_current_rank'
    ]
)

# Remove impossible ranking values
qs_rank = qs_rank[
    (qs_rank['home_team_current_rank'] > 0) &
    (qs_rank['away_team_current_rank'] > 0)
]

# Keep one row per match
qs_rank = qs_rank.drop_duplicates('match_id')

print('Matches after cleanup:', qs_rank['match_id'].nunique())

# Determine which player had the better ranking
# Lower ranking number = better ranking
qs_rank['better_rank_home'] = (
    qs_rank['home_team_current_rank'] <
    qs_rank['away_team_current_rank']
)

# Did the better-ranked player win the match?
qs_rank['better_ranked_player_won'] = (
    (qs_rank['better_rank_home'] & (qs_rank['winner_code'] == 1)) |
    (~qs_rank['better_rank_home'] & (qs_rank['winner_code'] == 2))
)

# Remove ranking ties
qs_rank = qs_rank[
    qs_rank['home_team_current_rank'] !=
    qs_rank['away_team_current_rank']
].copy()

# Calculate win percentage of the better-ranked player
better_rank_win_pct = (
    qs_rank['better_ranked_player_won'].mean() * 100
)

# Calculate average ranking difference
qs_rank['rank_difference'] = (
    qs_rank['away_team_current_rank'] -
    qs_rank['home_team_current_rank']
)

result_qs_rank = pd.DataFrame({
    'metric': [
        'better_ranked_player_wins_%',
        'lower_ranked_player_wins_%',
        'matches_analyzed',
        'average_rank_difference'
    ],
    'value': [
        round(better_rank_win_pct, 1),
        round(100 - better_rank_win_pct, 1),
        qs_rank['match_id'].nunique(),
        round(qs_rank['rank_difference'].abs().mean(), 1)
    ]
})

display(result_qs_rank)
# Out:
# Matches before cleanup: 1062
# Matches after cleanup: 327
#                         metric  value
# 0  better_ranked_player_wins_%   62.7
# 1   lower_ranked_player_wins_%   37.3
# 2             matches_analyzed  327.0
# 3      average_rank_difference  244.6

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Split data by winner (home or away)
home_wins = qs_rank[qs_rank['winner_code'] == 1]
away_wins = qs_rank[qs_rank['winner_code'] == 2]

# Scatter: home rank vs away rank, colored by winner
ax.scatter(
    home_wins['home_team_current_rank'],
    home_wins['away_team_current_rank'],
    alpha=0.35,
    color='steelblue',
    s=25,
    label='Home player won'
)

ax.scatter(
    away_wins['home_team_current_rank'],
    away_wins['away_team_current_rank'],
    alpha=0.35,
    color='salmon',
    s=25,
    label='Away player won'
)

# Diagonal line: equal rankings
max_rank = max(
    qs_rank['home_team_current_rank'].max(),
    qs_rank['away_team_current_rank'].max()
)
ax.plot(
    [0, max_rank],
    [0, max_rank],
    color='red',
    linestyle='--',
    linewidth=2,
    label='Equal ranking'
)

# Hide spines
ax.spines[["right", "left", "top"]].set_visible(False)

# Title
ax.set_title(
    "Ranking vs match outcome",
    loc="left",
    weight="bold",
    color="gray",
    fontsize=16
)

# Labels
ax.set_xlabel(
    "Home player ranking",
    weight="bold",
    color="gray",
    fontsize=14
)

ax.set_ylabel(
    "Away player ranking",
    weight="bold",
    color="gray",
    fontsize=14
)

# Tick styling
ax.tick_params(axis="x", colors="gray", labelsize="large")
ax.tick_params(axis="y", colors="gray", labelsize="large")
ax.tick_params(axis="x", which="major", length=0)

# Grid
ax.grid(linestyle="dashed", alpha=0.5)

# Legend
ax.legend(
    fontsize=11,
    frameon=False,
    labelcolor="gray"
)

plt.tight_layout()

plt.show()
